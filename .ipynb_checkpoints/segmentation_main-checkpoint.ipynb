# %% [markdown]
# # AI in Medicine I - Practical 2: Brain Tissue Segmentation
#
# Segmentation of different tissues from MRI scans of the brain is an important step for further downstream applications such as disease prediction, classification or brain age estimation.
#
# The goal of the coursework is to implement classical and deep learning approaches for segmentation of different tissue types in MRI scans of the brain, i.e., background, cerebrospinal fluid (CSF), white matter (WM), and gray matter (GM). We provide data from a total of 652 healthy subjects, that is split into different development sets and a hold-out test set on which you will evaluate your final segmentation accuracy.
# Each approach will require a processing pipeline with different components that you will need to implement using methods that were discussed in the lectures and tutorials. There are three dedicated parts in the Jupyter notebook for each approach which contain some detailed instructions and some helper code.
#
# **Make sure to select the correct runtime when working in Google Colab (GPU)**

# %% [markdown]
# ## Downloading the Data

# %%
! wget -q --show-progress https://www.dropbox.com/s/w9njau9t6rrheel/brainage-data.zip
! unzip -qq -o brainage-data.zip
! wget -q --show-progress https://www.dropbox.com/s/f5mt8p9pkszff3x/brainage-testdata.zip
! unzip -qq -o brainage-testdata.zip
# Out:
# zsh:1: command not found: wget
# unzip:  cannot find or open brainage-data.zip, brainage-data.zip.zip or brainage-data.zip.ZIP.
# zsh:1: command not found: wget
# unzip:  cannot find or open brainage-testdata.zip, brainage-testdata.zip.zip or brainage-testdata.zip.ZIP.

# %% [markdown]
# ## Imports

# %%
import os
import glob
import random
from argparse import Namespace
from functools import partial
from multiprocessing import Pool
from numbers import Number
from typing import Any, Dict
from typing import List, Tuple

import matplotlib.pyplot as plt
import seaborn as sns
import nibabel as nib
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from torch import Tensor
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm


def seed_everything(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.benchmark = False


def mean_absolute_error(preds: Tensor, targets: Tensor) -> float:
    """Compute the mean absolute error between predictions and targets"""
    return (preds.view(-1) - targets.view(-1)).abs().mean().item()


class TensorboardLogger(SummaryWriter):
    def __init__(
        self,
        log_dir: str = None,
        config: Namespace = None,
        enabled: bool = True,
        comment: str = '',
        purge_step: int = None,
        max_queue: int = 10,
        flush_secs: int = 120,
        filename_suffix: str = ''
    ):
        self.enabled = enabled
        if self.enabled:
            super().__init__(
                log_dir=log_dir,
                comment=comment,
                purge_step=purge_step,
                max_queue=max_queue,
                flush_secs=flush_secs,
                filename_suffix=filename_suffix
            )
        else:
            return

        # Add config
        if config is not None:
            self.add_hparams(
                {k: v for k, v in vars(config).items() if isinstance(
                    v, (int, float, str, bool, torch.Tensor))},
                {}
            )

    def log(self, data: Dict[str, Any], step: int) -> None:
        """Log each entry in data as its corresponding data type"""
        if self.enabled:
            for k, v in data.items():
                # Scalars
                if isinstance(v, Number):
                    self.add_scalar(k, v, step)

                # Images
                elif (isinstance(v, np.ndarray) or isinstance(v, torch.Tensor)) and len(v.shape) >= 3:
                    if len(v.shape) == 3:
                        self.add_image(k, v, step)
                    elif len(v.shape) == 4:
                        self.add_images(k, v, step)
                    else:
                        raise ValueError(f'Unsupported image shape: {v.shape}')

                # Matplotlib figures
                elif isinstance(v, plt.Figure):
                    self.add_figure(k, v, step)

                else:
                    raise ValueError(f'Unsupported data type: {type(v)}')


def load_nii(path: str, dtype: str = 'float32') -> np.ndarray:
    """Load an MRI scan from disk and convert it to a given datatype

    :param path: Path to file
    :param dtype: Target dtype
    :return img: Loaded image. Shape (H, W, D)
    """
    return nib.load(path).get_fdata().astype(np.dtype(dtype))


def load_segmentations(paths: str):
    """Load all segmentations and associated subject_ids"""
    filenames, segmentations = [], []
    for im in tqdm(paths):
        id = im.split('_brain_')[0].split('/')[-1].split('-')[1].split('_')[0]
        segmentations.append(load_nii(im))
        filenames.append(id)
    return filenames, np.array(segmentations)


def plot_segmentations(im: np.ndarray, seg: np.ndarray, i: int = 65, title: str = None):
    fig, ax = plt.subplots(2, 3, figsize=(20, 10))

    col = 2
    ax[0, col].imshow(np.rot90(im[..., i], k=3), cmap='gray')
    ax[0, col].imshow(np.rot90(seg[..., i], k=3),
                 alpha=0.5 * (np.rot90(seg[..., i] > 0, k=3)),
                 interpolation=None, cmap='jet')
    ax[1, col].imshow(np.rot90(im[..., i], k=3), cmap='gray')
    ax[0, col].set_title('Axial')

    k = 1
    col = 0
    ax[0, col].imshow(np.rot90(im[i, ...], k=k), cmap='gray')
    ax[0, col].imshow(np.rot90(seg[i, ...], k=k),
                 alpha=0.5 * (np.rot90(seg[i, ...] > 0, k=k)),
                 interpolation=None, cmap='jet')
    ax[1, col].imshow(np.rot90(im[i, ...], k=k), cmap='gray')
    ax[0, col].set_title('Sagittal')

    col = 1
    ax[0, col].imshow(np.rot90(im[:, i, :], k=k), cmap='gray')
    ax[0, col].imshow(np.rot90(seg[:, i, :], k=k),
                 alpha=0.5 * (np.rot90(seg[:, i, :] > 0, k=k)),
                 interpolation=None, cmap='jet')
    ax[1, col].imshow(np.rot90(im[:, i, :], k=k), cmap='gray')
    ax[0, col].set_title('Coronal')

    if title is not None:
        # plt.set_title(title)
        fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()



# %load_ext tensorboard
# %load_ext autoreload
# %autoreload 2
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Getting started and familiarise ourselves with the data
#
# We provide the data of 652 subjects from which we use 522 for training, 65 for validation, and the rest of 65 for testing your final model.

# %% [markdown]
# ## Imaging data
# Let's check out the imaging data that is available for each subject.

# %%
file = './data/brain_age/images/sub-CC110033_T1w_unbiased.nii.gz'

image = nib.load(file).get_fdata()

f, axarr = plt.subplots(1, 3, figsize=(20, 10))
H, W, D = image.shape
axarr[0].imshow(np.flip(image[H // 2, :, :].T, axis=0), cmap='gray')
axarr[1].imshow(np.flip(image[:, W // 2, :].T, axis=0), cmap='gray')
axarr[2].imshow(image[:, :, D // 2].T, cmap='gray')
plt.show()

# %%
paths = sorted(glob.glob('data/brain_age/segs_refs/*'))
filenames, segmentations = load_segmentations(paths)
# Out:
# 100%|████████████████████████████████████████████████████████████| 652/652 [00:02<00:00, 253.83it/s]

# %%
np.random.seed(10282022)

all_keys = np.asarray(range(len(filenames)))
ratio_test = int(0.1 * len(all_keys))  # 10% val; 10% test
val_keys = np.random.choice(all_keys, 2 * ratio_test, replace=False)
test_keys = np.random.choice(val_keys, ratio_test, replace=False)

train_files, val_files, test_files = [], [], []
segmentations_train, segmentations_val, segmentations_test =  [],  [], []
for scan_id in tqdm(all_keys):
  scan = f'data/brain_age/images/sub-{filenames[scan_id]}_T1w_unbiased.nii.gz'
  seg = segmentations[scan_id]
  if scan_id in test_keys:
      test_files.append(scan)
      segmentations_test.append(seg)
  elif scan_id in val_keys:
      val_files.append(scan)
      segmentations_val.append(seg)
  else:
      train_files.append(scan)
      segmentations_train.append(seg)
print(f'{len(train_files)} train files')
print(f'{len(val_files)} val files')
print(f'{len(test_files)} test files')
# Out:
# 100%|█████████████████████████████████████████████████████████| 652/652 [00:00<00:00, 293704.89it/s]
# 522 train files
# 65 val files
# 65 test files

# %% [markdown]
# Let's visualize one validations sample

# %%
im = load_nii(val_files[0])
plot_segmentations(im, segmentations_val[0], i=47, title='Example gt segmentation on the validation set')

# %% [markdown]
# # Task 1: Evaluation and Visualization

# %% [markdown]
# **Q1a**. We first have to define how good our predicted segmentations are. Implement the evaluation functions below.

# %%
np.unique(np.array(segmentations_test)[15])
# Out:
# array([0., 1., 2., 3.], dtype=float32)

# %%
# The Dice similarity coefficient is widely used for evaluating image segmentation alogrithms.
# Implement a method that computes the patient-wise Dice score, precision, and recall (mean and std) for the test dataset.
# Hint: Don't forget that there are multiple classes.
# --------------------------- ADD YOUR CODE HERE ------------------------------

def dice_coefficient_precision_recall(predictions, gt): 
  predictions = np.array(predictions)
  gt = np.array(gt)

  unique_classes = np.unique(gt)
  num_classes = len(unique_classes)
  num_patients = predictions.shape[0]

  dice = np.zeros((num_classes, num_patients))
  precision = np.zeros((num_classes, num_patients))
  recall = np.zeros((num_classes, num_patients))

  for patient_idx in range(num_patients):
      for i, cls in enumerate(unique_classes):
        pred = predictions[patient_idx, :, :, :]
        ground_truth = gt[patient_idx, :, :, :]

        true_positive = np.sum(np.logical_and(pred == cls, ground_truth == cls))
        false_positive = np.sum(np.logical_and(pred == cls, ground_truth != cls))
        false_negative = np.sum(np.logical_and(pred != cls, ground_truth == cls))

        # Calculate Dice, precision, and recall for the current class and patient
        dice[i, patient_idx] = (2.0 * true_positive) / (2.0 * true_positive + false_positive + false_negative + 1e-5)
        precision[i, patient_idx] = true_positive / (true_positive + false_positive + 1e-5)
        recall[i, patient_idx] = true_positive / (true_positive + false_negative + 1e-5)

  return dice, precision, recall
def Dice(predictions, gt):

  dice, _, _ = dice_coefficient_precision_recall(predictions, gt)
  mean, std = dice.mean(axis=0), dice.std(axis=0)
  return mean, std

def precision(predictions, gt):

  _, precision, _ = dice_coefficient_precision_recall(predictions, gt)
  mean, std = precision.mean(axis=0) , precision.std(axis=0)
  return mean, std

def recall(predictions, gt):

  _, _, recall = dice_coefficient_precision_recall(predictions, gt)
  mean, std = recall.mean(axis=0), recall.std(axis=0)
  return mean, std

# ----------------------------------- END -------------------------------------

# %% [markdown]
# **Q1b**. Next, we want to visualize the best- and worst-performing samples in the test set. Implement a function that evaluates the entire test dataset and outputs the index of the best and worst performing samples according to the Dice coefficient.

# %%
# You may change the functions below as you see fit

# --------------------------- ADD YOUR CODE HERE ------------------------------
def get_best_and_worst_ids(predictions):
    best_ids, worst_ids = -1, -1

    # TODO: implement
    dice_scores = Dice(predictions, segmentations_test)[0]

    # Find the index of the best and worst Dice scores
    best_ids = np.argmax(dice_scores)
    worst_ids = np.argmin(dice_scores)
    # print(dice_scores.shape)
    best_performance, worst_performance = dice_scores[best_ids], dice_scores[worst_ids]
    return {
        'best_id': best_ids,
        'best_performance': best_performance,
        'worst_id': worst_ids,
        'worst_performance': worst_performance
    }

def visualize_best_and_worst_samples(predictions, i_best=47, i_worst=47):
    return_dict = get_best_and_worst_ids(predictions)

    best_id = return_dict['best_id']
    plot_segmentations(load_nii(test_files[best_id]), predictions[best_id], i=i_best,
                       title=f'Best prediction on the test set (Dice: {return_dict["best_performance"]:.2f})')

    worst_id = return_dict['worst_id']
    plot_segmentations(load_nii(test_files[worst_id]), predictions[worst_id], i=i_worst,
                       title=f'Worst prediction on the test set (Dice: {return_dict["worst_performance"]:.2f})')
# ----------------------------------- END -------------------------------------

# %% [markdown]
# **Q1c**. Given a set of predictions for a number of models, create a summary figure of your choice (e.g. table, bar plot) which visualizes all of the metric values. Visualize multiple metrics (Dice coefficient, precision, and recall), each computed for every tissue type. A sample dictionary is provided below.

# %%
# --------------------------- ADD YOUR CODE HERE ------------------------------

def get_results_dictionary(predictions):
    results_dict = {}
    tissues = ['CSF', 'WM', 'GM']

    dice, precision, recall = dice_coefficient_precision_recall(predictions, segmentations_test)

    dice_tissue_mean = dice.mean(axis=1)
    precision_tissue_mean = precision.mean(axis=1)
    recall_tissue_mean = recall.mean(axis=1)

    for i, tissue in enumerate(tissues): 
        
        dict_ = {'dice': '-1', 'precision': '-1', 'recall': '-1'}

        dict_['dice'] = str(dice_tissue_mean[i + 1])
        dict_['precision'] = str(precision_tissue_mean[i + 1])
        dict_['recall'] = str(recall_tissue_mean[i + 1])
        
        results_dict[tissue] = dict_

    return results_dict

def plot_results_summary(results_dict: Dict[str, Dict[str, Dict[str, str]]]) -> None:
    
    tissues = list(next(iter(results_dict.values())).keys())
    metrics = ['dice', 'precision', 'recall']
    models = list(results_dict.keys())

    bar_width = 0.1
    index = np.arange(len(tissues))

    for metric in metrics:
        plt.figure(figsize=(10, 6))
        for i, model in enumerate(models):
            values = [float(results_dict[model][tissue][metric]) for tissue in tissues]
            plt.bar(index + i * bar_width, values, bar_width, label=model)

        plt.xlabel('Tissue Type')
        plt.ylabel(metric.capitalize())
        plt.title(f'{metric.capitalize()} Comparison for Different Models')
        plt.xticks(index + (len(models) / 2) * bar_width, tissues)
        plt.legend()

        plt.show()
# ----------------------------------- END -------------------------------------

sample_results = {
    'baseline1': {
        'CSF': {'dice': '0.7', 'precision': '0.82', 'recall': '0.6'},
        'WM': {'dice': '0.72', 'precision': '0.86', 'recall': '0.61'},
        'GM': {'dice': '0.74', 'precision': '0.88', 'recall': '0.59'},
    },
    'baseline2': {
        'CSF': {'dice': '0.6', 'precision': '0.5', 'recall': '0.7'},
        'WM': {'dice': '0.61', 'precision': '0.46', 'recall': '0.72'},
        'GM': {'dice': '0.9', 'precision': '0.88', 'recall': '0.92'},
    }
}
plot_results_summary(sample_results)

# %% [markdown]
# # Task 2: Unsupervised segmentation

# %% [markdown]
# The first approach aims to segment the brain tissues, including grey matter (GM), white matter (WM), cerebrospinal fluid (CSF), and background using unsupervised classical machine learning techniques.
#
# Different unsupervised techniques to leverage the different intensity profile of the tissues should be explored.

# %%
slice_id = 0
im_ = load_nii(val_files[slice_id])[:,:,47].flatten()
seg_ = segmentations_val[slice_id][:,:,47].flatten()

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharey=False)
fig.suptitle('Intensity Density Plot')

sns.kdeplot(im_, ax=axes[0], fill=True)
axes[0].set_title('Input')

sns.kdeplot(im_[np.argwhere(seg_ == 0)][:, 0], ax=axes[1], fill=True, color='#85929E', label='Background', legend=True)
sns.kdeplot(im_[np.argwhere(seg_ == 1)][:, 0], ax=axes[1], fill=True, color='#9FE2BF', label='CSF', legend=True)
sns.kdeplot(im_[np.argwhere(seg_ == 3)][:, 0], ax=axes[1], fill=True, color='#CD5C5C', label='WM', legend=True)
sns.kdeplot(im_[np.argwhere(seg_ == 2)][:, 0], ax=axes[1], fill=True, color='#6495ED', label='GM', legend=True)
axes[1].set_ylim(0, 0.05)
axes[1].set_title('Ground truth')
plt.legend(loc=9, labels=['Background', 'CSF', 'WM', 'GM'])

# %% [markdown]
# ## Unsupervised Learning
#
# Here, you should experiment with different *classical* unsupervised machine learning methods, e.g., clustering, density estimation, etc... (at least two different methods). Hint: sklearn has implementations of unsupervised methods
#
# **HINT**: You can predict the different classes of intensities even without any training!
#
# **HINT**: You can evaluate every volume slice-by-slice if the whole volume does not fit in the memory.

# %% [markdown]
# #### QUESTION Q2a.
# Implement an unsupervised learning method of your choice.
# Evaluate the Dice scores (separately for every tissue type) for the whole test set using method 1.

# %%
# Unsupervised method 1
# --------------------------- ADD YOUR CODE HERE ------------------------------
'''
========== Report ==========
Image Loading and Reshaping:
The code loads medical images using load_nii and reshapes them to a flat 1D array.
KMeans Clustering:
Utilizes the KMeans clustering algorithm from scikit-learn to cluster the voxel intensities into four clusters.
Finding Right Cluster Indexes:
Generates combinations of four values (indexes) and applies them to the clustered labels, selecting the 
combination that maximizes the Dice similarity coefficient with the ground truth segmentation.
Performance Evaluation:
Computes the Dice score by comparing the predicted segmentation with the ground truth segmentation.
'''

from sklearn.cluster import KMeans

H, W, D = load_nii(test_files[0]).shape
pred_seg_1 = np.array([], dtype=np.int64).reshape(0, H, W, D)

for x in range(len(test_files)):
    # print(f'========== Image {x+1} ==========')
    
    # image loading and reshaping
    im_ = load_nii(test_files[x])
    im_flat = im_.reshape(-1, 1)

    # clustering
    clusters = 4
    kmeans = KMeans(n_clusters=clusters, random_state=42, n_init='auto').fit(im_flat)
    im_flat_labels = kmeans.labels_
    im_labels = im_flat_labels.reshape(1, H, W, D)

    # find right cluster indexes
    im_cluster = np.array([], dtype=np.int64).reshape(0, H, W, D)
    
    values = np.arange(4)
    i, j, k, l = np.meshgrid(values, values, values, values)
    i_flat, j_flat, k_flat, l_flat = i.flatten(), j.flatten(), k.flatten(), l.flatten()

    comparison_ = np.array([])
    
    count = 1
    for i_val, j_val, k_val, l_val in zip(i_flat, j_flat, k_flat, l_flat):
        if i_val != j_val and i_val != k_val and i_val != l_val and j_val != k_val and j_val != l_val and k_val != l_val: 
            # print(f"{count} - - - i: {i_val}, j: {j_val}, k: {k_val}, l: {l_val}")
            count += 1

            copy_im_labels = im_labels.copy()
            
            vals = np.array([i_val, j_val, k_val, l_val])
            for m in range(4):
                indices = np.argwhere(im_labels == m)
                copy_im_labels[indices[:, 0], indices[:, 1], indices[:, 2], indices[:, 3]] = vals[m]
            
            im_cluster = np.vstack((im_cluster, copy_im_labels))
            
            comparison = np.equal(copy_im_labels.reshape(H, W, D), segmentations_test[x])
            comparison_result = comparison.astype(int)
            comparison_sum = np.sum(comparison_result)
            comparison_ = np.append(comparison_, comparison_sum)
                
    best_id = np.argmax(comparison_)
    pred_seg_1 = np.vstack((pred_seg_1, im_cluster[best_id].reshape(1, H, W, D)))
    
    print(pred_seg_1.shape)
# ----------------------------------- END -------------------------------------
# Out:
# (1, 98, 116, 94)
# (2, 98, 116, 94)
# (3, 98, 116, 94)
# (4, 98, 116, 94)
# (5, 98, 116, 94)
# (6, 98, 116, 94)
# (7, 98, 116, 94)
# (8, 98, 116, 94)
# (9, 98, 116, 94)
# (10, 98, 116, 94)
# (11, 98, 116, 94)
# (12, 98, 116, 94)
# (13, 98, 116, 94)
# (14, 98, 116, 94)
# (15, 98, 116, 94)
# (16, 98, 116, 94)
# (17, 98, 116, 94)
# (18, 98, 116, 94)
# (19, 98, 116, 94)
# (20, 98, 116, 94)
# (21, 98, 116, 94)
# (22, 98, 116, 94)
# (23, 98, 116, 94)
# (24, 98, 116, 94)
# (25, 98, 116, 94)
# (26, 98, 116, 94)
# (27, 98, 116, 94)
# (28, 98, 116, 94)
# (29, 98, 116, 94)
# (30, 98, 116, 94)
# (31, 98, 116, 94)
# (32, 98, 116, 94)
# (33, 98, 116, 94)
# (34, 98, 116, 94)
# (35, 98, 116, 94)
# (36, 98, 116, 94)
# (37, 98, 116, 94)
# (38, 98, 116, 94)
# (39, 98, 116, 94)
# (40, 98, 116, 94)
# (41, 98, 116, 94)
# (42, 98, 116, 94)
# (43, 98, 116, 94)
# (44, 98, 116, 94)
# (45, 98, 116, 94)
# (46, 98, 116, 94)
# (47, 98, 116, 94)
# (48, 98, 116, 94)
# (49, 98, 116, 94)
# (50, 98, 116, 94)
# (51, 98, 116, 94)
# (52, 98, 116, 94)
# (53, 98, 116, 94)
# (54, 98, 116, 94)
# (55, 98, 116, 94)
# (56, 98, 116, 94)
# (57, 98, 116, 94)
# (58, 98, 116, 94)
# (59, 98, 116, 94)
# (60, 98, 116, 94)
# (61, 98, 116, 94)
# (62, 98, 116, 94)
# (63, 98, 116, 94)
# (64, 98, 116, 94)
# (65, 98, 116, 94)

# %%
# Plot the obtained results for volume 0 and axial slice 47 of the test set (density estimations)
# --------------------------- ADD YOUR CODE HERE ------------------------------
def densityEstimations(pred_seg_):
    volume = 0
    slice_id = 47
    im_ = load_nii(test_files[volume])[:,:,slice_id].flatten()
    pred_ = pred_seg_[volume][:, :, slice_id].flatten()
    seg_ = segmentations_test[volume][:,:,slice_id].flatten()

    fig, axes = plt.subplots(1, 3, figsize=(18, 4), sharey=False)
    fig.suptitle('Intensity Density Plot')

    sns.kdeplot(im_, ax=axes[0], fill=True)
    axes[0].set_title('Input')

    sns.kdeplot(im_[np.argwhere(seg_ == 0)][:, 0], ax=axes[1], fill=True, color='#85929E', label='Background', legend=True)
    sns.kdeplot(im_[np.argwhere(seg_ == 1)][:, 0], ax=axes[1], fill=True, color='#9FE2BF', label='CSF', legend=True)
    sns.kdeplot(im_[np.argwhere(seg_ == 3)][:, 0], ax=axes[1], fill=True, color='#CD5C5C', label='WM', legend=True)
    sns.kdeplot(im_[np.argwhere(seg_ == 2)][:, 0], ax=axes[1], fill=True, color='#6495ED', label='GM', legend=True)
    axes[1].set_ylim(0, 0.05)
    axes[1].set_title('Ground truth')
    axes[1].legend(loc='upper right', labels=['Background', 'CSF', 'WM', 'GM'])

    sns.kdeplot(im_[np.argwhere(pred_ == 0)][:, 0], ax=axes[2], fill=True, color='#85929E', label='Background', legend=True)
    sns.kdeplot(im_[np.argwhere(pred_ == 1)][:, 0], ax=axes[2], fill=True, color='#9FE2BF', label='CSF', legend=True)
    sns.kdeplot(im_[np.argwhere(pred_ == 3)][:, 0], ax=axes[2], fill=True, color='#CD5C5C', label='WM', legend=True)
    sns.kdeplot(im_[np.argwhere(pred_ == 2)][:, 0], ax=axes[2], fill=True, color='#6495ED', label='GM', legend=True)
    axes[2].set_ylim(0, 0.05)
    axes[2].set_title('Prediction')
    axes[2].legend(loc='upper right', labels=['Background', 'CSF', 'WM', 'GM'])
densityEstimations(pred_seg_1)
# ----------------------------------- END -------------------------------------

# %%
# Visualize the best and worst predictions on the test set for method 1
visualize_best_and_worst_samples(pred_seg_1)

# %% [markdown]
# #### QUESTION Q2b.
# Implement a second unsupervised learning method of your choice.
# Evaluate the Dice scores (separately for every tissue type) for the whole test set using method 2.

# %%
# Unsupervised method 2
# --------------------------- ADD YOUR CODE HERE ------------------------------

# 4 components which are grey matter (GM), white matter (WM), cerebrospinal fluid (CSF), and background 

def image_data_load(image_files):
    original_images = []
    flatted_images = []
    for i in range(len(image_files)):
        image = load_nii(image_files[i])   # image_shape 98,116,94
        original_images.append(image)
        image = image.reshape(-1,1)
        flatted_images.append(image)
    return original_images, flatted_images

def reconstruct_images(labels, original_shape):
    return labels.reshape(original_shape)

train_images, flatted_train_images = image_data_load(train_files)
test_images, flatted_test_images = image_data_load(test_files)

# %%
from sklearn.mixture import GaussianMixture as GMM

gmm_models = [] 

def model_training(train_files): #Gaussian Mixture Model
    
    for i in range(len(train_files)):
        gmm_model = GMM(n_components=4).fit(flatted_train_images[i])
        gmm_models.append(gmm_model)  # Store the trained model in the list

        # Print the weights of the components
        print(f"Weights for GMM model {i}: {gmm_model.weights_}")

        print(f"Trained GMM for image {i}")
    
    print("okey")
    return gmm_model

model = model_training(train_files)
# Out:
# Weights for GMM model 0: [0.82934461 0.07807395 0.03617647 0.05640497]
# Trained GMM for image 0
# Weights for GMM model 1: [0.83277794 0.07996418 0.05392105 0.03333683]
# Trained GMM for image 1
# Weights for GMM model 2: [0.05440299 0.84544422 0.07150119 0.0286516 ]
# Trained GMM for image 2
# Weights for GMM model 3: [0.81180203 0.05957794 0.03400424 0.09461579]
# Trained GMM for image 3
# Weights for GMM model 4: [0.8314668  0.06960429 0.05932598 0.03960293]
# Trained GMM for image 4
# Weights for GMM model 5: [0.84409658 0.05056876 0.03374959 0.07158507]
# Trained GMM for image 5
# Weights for GMM model 6: [0.81623452 0.08424342 0.0419119  0.05761016]
# Trained GMM for image 6
# Weights for GMM model 7: [0.08389236 0.81042711 0.06465298 0.04102755]
# Trained GMM for image 7
# Weights for GMM model 8: [0.82274014 0.08848609 0.03288993 0.05588384]
# Trained GMM for image 8
# Weights for GMM model 9: [0.86654157 0.06306288 0.04555002 0.02484553]
# Trained GMM for image 9
# Weights for GMM model 10: [0.83851266 0.08041437 0.03562745 0.04544552]
# Trained GMM for image 10
# Weights for GMM model 11: [0.83695264 0.07561418 0.05352459 0.03390858]
# Trained GMM for image 11
# Weights for GMM model 12: [0.8122435  0.06079975 0.09365969 0.03329706]
# Trained GMM for image 12
# Weights for GMM model 13: [0.09671124 0.79489828 0.06482727 0.0435632 ]
# Trained GMM for image 13
# Weights for GMM model 14: [0.81383751 0.0813869  0.04202275 0.06275283]
# Trained GMM for image 14
# Weights for GMM model 15: [0.79636486 0.08864424 0.07681616 0.03817474]
# Trained GMM for image 15
# Weights for GMM model 16: [0.79921607 0.08750673 0.07386041 0.03941679]
# Trained GMM for image 16
# Weights for GMM model 17: [0.80868367 0.09325947 0.03783947 0.06021739]
# Trained GMM for image 17
# Weights for GMM model 18: [0.83383547 0.05518261 0.03435182 0.0766301 ]
# Trained GMM for image 18
# Weights for GMM model 19: [0.84948404 0.07468504 0.05067545 0.02515547]
# Trained GMM for image 19
# Weights for GMM model 20: [0.80587359 0.07079538 0.03920343 0.0841276 ]
# Trained GMM for image 20
# Weights for GMM model 21: [0.78719395 0.10015608 0.04227452 0.07037545]
# Trained GMM for image 21
# Weights for GMM model 22: [0.80987417 0.05880297 0.09038692 0.04093594]
# Trained GMM for image 22
# Weights for GMM model 23: [0.84290342 0.05078479 0.07666479 0.02964699]
# Trained GMM for image 23
# Weights for GMM model 24: [0.83052079 0.05610832 0.03621638 0.07715452]
# Trained GMM for image 24
# Weights for GMM model 25: [0.84369611 0.07293307 0.03296963 0.05040119]
# Trained GMM for image 25
# Weights for GMM model 26: [0.83837041 0.07845263 0.05071817 0.03245879]
# Trained GMM for image 26
# Weights for GMM model 27: [0.85518569 0.06254924 0.03065492 0.05161015]
# Trained GMM for image 27
# Weights for GMM model 28: [0.8138549  0.08890601 0.06233152 0.03490757]
# Trained GMM for image 28
# Weights for GMM model 29: [0.81752905 0.08441609 0.0592597  0.03879516]
# Trained GMM for image 29
# Weights for GMM model 30: [0.03454406 0.05242652 0.06995751 0.84307191]
# Trained GMM for image 30
# Weights for GMM model 31: [0.82264404 0.05594096 0.0316965  0.08971851]
# Trained GMM for image 31
# Weights for GMM model 32: [0.82215159 0.05761124 0.08888834 0.03134883]
# Trained GMM for image 32
# Weights for GMM model 33: [0.82360145 0.07932265 0.05742889 0.03964701]
# Trained GMM for image 33
# Weights for GMM model 34: [0.8218436  0.08232123 0.06375053 0.03208464]
# Trained GMM for image 34
# Weights for GMM model 35: [0.82798988 0.0810484  0.05313266 0.03782907]
# Trained GMM for image 35
# Weights for GMM model 36: [0.80434018 0.06718174 0.09085291 0.03762517]
# Trained GMM for image 36
# Weights for GMM model 37: [0.03655606 0.80862741 0.06654584 0.0882707 ]
# Trained GMM for image 37
# Weights for GMM model 38: [0.82091294 0.0825412  0.06273201 0.03381385]
# Trained GMM for image 38
# Weights for GMM model 39: [0.85473126 0.02897176 0.04826026 0.06803672]
# Trained GMM for image 39
# Weights for GMM model 40: [0.83264698 0.07932813 0.03330644 0.05471844]
# Trained GMM for image 40
# Weights for GMM model 41: [0.82578445 0.05548661 0.03569898 0.08302996]
# Trained GMM for image 41
# Weights for GMM model 42: [0.83395337 0.07478485 0.05477559 0.03648618]
# Trained GMM for image 42
# Weights for GMM model 43: [0.77567667 0.07343342 0.1077124  0.04317751]
# Trained GMM for image 43
# Weights for GMM model 44: [0.81692254 0.06380909 0.08153715 0.03773121]
# Trained GMM for image 44
# Weights for GMM model 45: [0.81665787 0.08301322 0.05589624 0.04443267]
# Trained GMM for image 45
# Weights for GMM model 46: [0.80467574 0.06456554 0.03558435 0.09517437]
# Trained GMM for image 46
# Weights for GMM model 47: [0.07781473 0.82743228 0.056353   0.03839999]
# Trained GMM for image 47
# Weights for GMM model 48: [0.83252947 0.07516675 0.03301397 0.05928981]
# Trained GMM for image 48
# Weights for GMM model 49: [0.84516277 0.07105295 0.0353796  0.04840469]
# Trained GMM for image 49
# Weights for GMM model 50: [0.06704496 0.84731102 0.05331582 0.0323282 ]
# Trained GMM for image 50
# Weights for GMM model 51: [0.84726897 0.07296857 0.04954212 0.03022034]
# Trained GMM for image 51
# Weights for GMM model 52: [0.84678915 0.06967967 0.05474152 0.02878966]
# Trained GMM for image 52
# Weights for GMM model 53: [0.84621719 0.06864461 0.03167326 0.05346495]
# Trained GMM for image 53
# Weights for GMM model 54: [0.80229901 0.07016527 0.08378925 0.04374646]
# Trained GMM for image 54
# Weights for GMM model 55: [0.84723219 0.07426541 0.04631221 0.03219019]
# Trained GMM for image 55
# Weights for GMM model 56: [0.79659317 0.07199913 0.04271126 0.08869645]
# Trained GMM for image 56
# Weights for GMM model 57: [0.84490917 0.05256203 0.02869036 0.07383843]
# Trained GMM for image 57
# Weights for GMM model 58: [0.83336478 0.07208112 0.03287245 0.06168165]
# Trained GMM for image 58
# Weights for GMM model 59: [0.83087578 0.0603511  0.03579302 0.0729801 ]
# Trained GMM for image 59
# Weights for GMM model 60: [0.83064226 0.08189645 0.05345979 0.0340015 ]
# Trained GMM for image 60
# Weights for GMM model 61: [0.84783893 0.06841618 0.03332001 0.05042488]
# Trained GMM for image 61
# Weights for GMM model 62: [0.83254031 0.07135555 0.0577629  0.03834124]
# Trained GMM for image 62
# Weights for GMM model 63: [0.84107599 0.05348803 0.03559563 0.06984035]
# Trained GMM for image 63
# Weights for GMM model 64: [0.81252982 0.08724096 0.03896067 0.06126854]
# Trained GMM for image 64
# Weights for GMM model 65: [0.02733943 0.0550361  0.84333086 0.07429361]
# Trained GMM for image 65
# Weights for GMM model 66: [0.07237014 0.83590534 0.0562404  0.03548413]
# Trained GMM for image 66
# Weights for GMM model 67: [0.82264381 0.08133322 0.06164806 0.03437491]
# Trained GMM for image 67
# Weights for GMM model 68: [0.83900418 0.07414225 0.03388648 0.05296709]
# Trained GMM for image 68
# Weights for GMM model 69: [0.03500114 0.82482097 0.08205428 0.05812362]
# Trained GMM for image 69
# Weights for GMM model 70: [0.06800229 0.81460549 0.03913707 0.07825515]
# Trained GMM for image 70
# Weights for GMM model 71: [0.8376545  0.07629234 0.03394286 0.05211029]
# Trained GMM for image 71
# Weights for GMM model 72: [0.07068311 0.83855476 0.05369488 0.03706725]
# Trained GMM for image 72
# Weights for GMM model 73: [0.80539792 0.08572174 0.07069485 0.03818549]
# Trained GMM for image 73
# Weights for GMM model 74: [0.80545234 0.07009909 0.08599841 0.03845016]
# Trained GMM for image 74
# Weights for GMM model 75: [0.85504048 0.06486435 0.03686048 0.04323469]
# Trained GMM for image 75
# Weights for GMM model 76: [0.03734635 0.82107824 0.06202128 0.07955412]
# Trained GMM for image 76
# Weights for GMM model 77: [0.8321694  0.07193677 0.03526432 0.06062951]
# Trained GMM for image 77
# Weights for GMM model 78: [0.03251907 0.83728104 0.05459988 0.07560001]
# Trained GMM for image 78
# Weights for GMM model 79: [0.82526012 0.07636815 0.03625546 0.06211627]
# Trained GMM for image 79
# Weights for GMM model 80: [0.7788001  0.07662516 0.09845348 0.04612126]
# Trained GMM for image 80
# Weights for GMM model 81: [0.05952073 0.81730147 0.07807082 0.04510697]
# Trained GMM for image 81
# Weights for GMM model 82: [0.04993366 0.84588266 0.07333553 0.03084816]
# Trained GMM for image 82
# Weights for GMM model 83: [0.8167251  0.08074888 0.04140536 0.06112066]
# Trained GMM for image 83
# Weights for GMM model 84: [0.81577339 0.08164379 0.04385651 0.05872631]
# Trained GMM for image 84
# Weights for GMM model 85: [0.82375892 0.06090061 0.03619993 0.07914054]
# Trained GMM for image 85
# Weights for GMM model 86: [0.06970976 0.80610178 0.07824874 0.04593973]
# Trained GMM for image 86
# Weights for GMM model 87: [0.81935869 0.0845661  0.04149997 0.05457523]
# Trained GMM for image 87
# Weights for GMM model 88: [0.82627636 0.07688119 0.05747536 0.03936709]
# Trained GMM for image 88
# Weights for GMM model 89: [0.81854141 0.05738973 0.08536846 0.0387004 ]
# Trained GMM for image 89
# Weights for GMM model 90: [0.83165506 0.07231211 0.04370681 0.05232603]
# Trained GMM for image 90
# Weights for GMM model 91: [0.77691285 0.07742824 0.0565096  0.0891493 ]
# Trained GMM for image 91
# Weights for GMM model 92: [0.82072428 0.08243282 0.05987289 0.03697001]
# Trained GMM for image 92
# Weights for GMM model 93: [0.86320884 0.06316476 0.03233315 0.04129325]
# Trained GMM for image 93
# Weights for GMM model 94: [0.08310177 0.81693963 0.0601955  0.03976311]
# Trained GMM for image 94
# Weights for GMM model 95: [0.80726042 0.08003011 0.06894485 0.04376462]
# Trained GMM for image 95
# Weights for GMM model 96: [0.83969159 0.07061583 0.05443413 0.03525845]
# Trained GMM for image 96
# Weights for GMM model 97: [0.05709834 0.81950835 0.08545803 0.03793527]
# Trained GMM for image 97
# Weights for GMM model 98: [0.06631578 0.820328   0.07696896 0.03638726]
# Trained GMM for image 98
# Weights for GMM model 99: [0.82954394 0.07773282 0.05758965 0.03513359]
# Trained GMM for image 99
# Weights for GMM model 100: [0.84603727 0.07053231 0.03255907 0.05087134]
# Trained GMM for image 100
# Weights for GMM model 101: [0.81718535 0.07930666 0.06419428 0.03931372]
# Trained GMM for image 101
# Weights for GMM model 102: [0.07377073 0.83715793 0.0338768  0.05519454]
# Trained GMM for image 102
# Weights for GMM model 103: [0.80705183 0.06750975 0.03477468 0.09066374]
# Trained GMM for image 103
# Weights for GMM model 104: [0.81086874 0.07635199 0.0721447  0.04063457]
# Trained GMM for image 104
# Weights for GMM model 105: [0.06586845 0.82043089 0.08351891 0.03018174]
# Trained GMM for image 105
# Weights for GMM model 106: [0.85793635 0.06821656 0.04691519 0.0269319 ]
# Trained GMM for image 106
# Weights for GMM model 107: [0.82728757 0.05640646 0.03421888 0.08208708]
# Trained GMM for image 107
# Weights for GMM model 108: [0.82306729 0.08337153 0.06060977 0.03295141]
# Trained GMM for image 108
# Weights for GMM model 109: [0.8147328  0.08498437 0.05806073 0.04222209]
# Trained GMM for image 109
# Weights for GMM model 110: [0.80112481 0.06858536 0.04488644 0.08540339]
# Trained GMM for image 110
# Weights for GMM model 111: [0.83065185 0.07618977 0.05561741 0.03754097]
# Trained GMM for image 111
# Weights for GMM model 112: [0.81828519 0.08057    0.06259448 0.03855033]
# Trained GMM for image 112
# Weights for GMM model 113: [0.06178545 0.8147974  0.08673971 0.03667744]
# Trained GMM for image 113
# Weights for GMM model 114: [0.82628999 0.07391656 0.03756212 0.06223133]
# Trained GMM for image 114
# Weights for GMM model 115: [0.80394292 0.07001115 0.04242748 0.08361845]
# Trained GMM for image 115
# Weights for GMM model 116: [0.84719886 0.07415106 0.02976308 0.048887  ]
# Trained GMM for image 116
# Weights for GMM model 117: [0.03294854 0.8448783  0.05141895 0.07075422]
# Trained GMM for image 117
# Weights for GMM model 118: [0.8232986  0.07950456 0.06133431 0.03586253]
# Trained GMM for image 118
# Weights for GMM model 119: [0.07044438 0.79821139 0.08552349 0.04582075]
# Trained GMM for image 119
# Weights for GMM model 120: [0.05851261 0.83020227 0.07155949 0.03972563]
# Trained GMM for image 120
# Weights for GMM model 121: [0.80393648 0.08242461 0.06575665 0.04788225]
# Trained GMM for image 121
# Weights for GMM model 122: [0.81977549 0.07670496 0.06555896 0.0379606 ]
# Trained GMM for image 122
# Weights for GMM model 123: [0.82875953 0.0832767  0.05571847 0.03224529]
# Trained GMM for image 123
# Weights for GMM model 124: [0.05792836 0.82897969 0.03757025 0.07552169]
# Trained GMM for image 124
# Weights for GMM model 125: [0.81633412 0.08345469 0.06226774 0.03794345]
# Trained GMM for image 125
# Weights for GMM model 126: [0.08500101 0.79225178 0.04633193 0.07641529]
# Trained GMM for image 126
# Weights for GMM model 127: [0.80508001 0.08203691 0.07668366 0.03619941]
# Trained GMM for image 127
# Weights for GMM model 128: [0.81244182 0.08567633 0.03689397 0.06498788]
# Trained GMM for image 128
# Weights for GMM model 129: [0.08130498 0.81562274 0.06758798 0.0354843 ]
# Trained GMM for image 129
# Weights for GMM model 130: [0.84121302 0.05733587 0.06527741 0.0361737 ]
# Trained GMM for image 130
# Weights for GMM model 131: [0.85172916 0.06362961 0.05956632 0.02507491]
# Trained GMM for image 131
# Weights for GMM model 132: [0.81976647 0.07963981 0.06428668 0.03630704]
# Trained GMM for image 132
# Weights for GMM model 133: [0.8155937  0.08479526 0.03527334 0.0643377 ]
# Trained GMM for image 133
# Weights for GMM model 134: [0.81742697 0.06829212 0.05079931 0.0634816 ]
# Trained GMM for image 134
# Weights for GMM model 135: [0.81251265 0.06598959 0.08532285 0.03617491]
# Trained GMM for image 135
# Weights for GMM model 136: [0.83678882 0.072232   0.05079595 0.04018323]
# Trained GMM for image 136
# Weights for GMM model 137: [0.81070598 0.07216253 0.08160403 0.03552746]
# Trained GMM for image 137
# Weights for GMM model 138: [0.79733079 0.07258035 0.0795789  0.05050997]
# Trained GMM for image 138
# Weights for GMM model 139: [0.82803901 0.05997629 0.07217772 0.03980697]
# Trained GMM for image 139
# Weights for GMM model 140: [0.82607101 0.05902079 0.03866457 0.07624363]
# Trained GMM for image 140
# Weights for GMM model 141: [0.84115053 0.05088479 0.03838064 0.06958405]
# Trained GMM for image 141
# Weights for GMM model 142: [0.81910754 0.0629599  0.07806371 0.03986884]
# Trained GMM for image 142
# Weights for GMM model 143: [0.81809372 0.07458614 0.04323287 0.06408727]
# Trained GMM for image 143
# Weights for GMM model 144: [0.06016378 0.8313747  0.07065387 0.03780765]
# Trained GMM for image 144
# Weights for GMM model 145: [0.08017822 0.82606717 0.06057116 0.03318345]
# Trained GMM for image 145
# Weights for GMM model 146: [0.81678135 0.08191816 0.0327283  0.0685722 ]
# Trained GMM for image 146
# Weights for GMM model 147: [0.81446932 0.06766877 0.07415897 0.04370295]
# Trained GMM for image 147
# Weights for GMM model 148: [0.81277124 0.08145446 0.06750226 0.03827205]
# Trained GMM for image 148
# Weights for GMM model 149: [0.80727254 0.08274971 0.0412895  0.06868826]
# Trained GMM for image 149
# Weights for GMM model 150: [0.80444812 0.07869442 0.07157062 0.04528684]
# Trained GMM for image 150
# Weights for GMM model 151: [0.8236126  0.06278098 0.07592706 0.03767936]
# Trained GMM for image 151
# Weights for GMM model 152: [0.05131915 0.84168759 0.07022154 0.03677173]
# Trained GMM for image 152
# Weights for GMM model 153: [0.03908515 0.81520817 0.06627954 0.07942714]
# Trained GMM for image 153
# Weights for GMM model 154: [0.05550644 0.83540281 0.03959055 0.06950021]
# Trained GMM for image 154
# Weights for GMM model 155: [0.82035973 0.06322949 0.04199237 0.07441842]
# Trained GMM for image 155
# Weights for GMM model 156: [0.805878   0.07225742 0.08554323 0.03632135]
# Trained GMM for image 156
# Weights for GMM model 157: [0.07118902 0.83703409 0.04055508 0.05122181]
# Trained GMM for image 157
# Weights for GMM model 158: [0.82837684 0.0602185  0.07381958 0.03758508]
# Trained GMM for image 158
# Weights for GMM model 159: [0.8204874  0.0760837  0.03998859 0.0634403 ]
# Trained GMM for image 159
# Weights for GMM model 160: [0.82180459 0.07206013 0.06761778 0.0385175 ]
# Trained GMM for image 160
# Weights for GMM model 161: [0.04044236 0.08157469 0.06481489 0.81316805]
# Trained GMM for image 161
# Weights for GMM model 162: [0.84671351 0.06520729 0.05472668 0.03335251]
# Trained GMM for image 162
# Weights for GMM model 163: [0.85654708 0.05485912 0.02844826 0.06014554]
# Trained GMM for image 163
# Weights for GMM model 164: [0.84804732 0.06402878 0.03732094 0.05060296]
# Trained GMM for image 164
# Weights for GMM model 165: [0.79351699 0.0824916  0.04408843 0.07990298]
# Trained GMM for image 165
# Weights for GMM model 166: [0.07379275 0.81728795 0.04487574 0.06404356]
# Trained GMM for image 166
# Weights for GMM model 167: [0.80338387 0.08106968 0.07452778 0.04101867]
# Trained GMM for image 167
# Weights for GMM model 168: [0.82298457 0.07583283 0.03413284 0.06704975]
# Trained GMM for image 168
# Weights for GMM model 169: [0.81747843 0.06006362 0.079632   0.04282595]
# Trained GMM for image 169
# Weights for GMM model 170: [0.81152053 0.06939308 0.04424513 0.07484125]
# Trained GMM for image 170
# Weights for GMM model 171: [0.80800808 0.07447812 0.07890147 0.03861234]
# Trained GMM for image 171
# Weights for GMM model 172: [0.05411909 0.83877306 0.03798649 0.06912136]
# Trained GMM for image 172
# Weights for GMM model 173: [0.79335092 0.09468456 0.04721975 0.06474477]
# Trained GMM for image 173
# Weights for GMM model 174: [0.84533564 0.06899224 0.03304698 0.05262513]
# Trained GMM for image 174
# Weights for GMM model 175: [0.07633365 0.81822243 0.06942318 0.03602074]
# Trained GMM for image 175
# Weights for GMM model 176: [0.79811778 0.07515675 0.03636445 0.09036102]
# Trained GMM for image 176
# Weights for GMM model 177: [0.83598011 0.0589847  0.07188374 0.03315145]
# Trained GMM for image 177
# Weights for GMM model 178: [0.05821766 0.83116934 0.07060582 0.04000718]
# Trained GMM for image 178
# Weights for GMM model 179: [0.82840209 0.07323341 0.05731751 0.04104699]
# Trained GMM for image 179
# Weights for GMM model 180: [0.06076457 0.82865871 0.07228821 0.03828851]
# Trained GMM for image 180
# Weights for GMM model 181: [0.84187598 0.07460791 0.05389793 0.02961818]
# Trained GMM for image 181
# Weights for GMM model 182: [0.83391054 0.07402928 0.03683601 0.05522417]
# Trained GMM for image 182
# Weights for GMM model 183: [0.85757383 0.04792762 0.06308482 0.03141373]
# Trained GMM for image 183
# Weights for GMM model 184: [0.06416821 0.84196959 0.05268835 0.04117385]
# Trained GMM for image 184
# Weights for GMM model 185: [0.83679345 0.0711952  0.03660037 0.05541097]
# Trained GMM for image 185
# Weights for GMM model 186: [0.81539064 0.07854569 0.06351382 0.04254984]
# Trained GMM for image 186
# Weights for GMM model 187: [0.79608061 0.09143178 0.0653295  0.04715811]
# Trained GMM for image 187
# Weights for GMM model 188: [0.09465795 0.80075746 0.06770157 0.03688302]
# Trained GMM for image 188
# Weights for GMM model 189: [0.8081033  0.07634003 0.04923009 0.06632658]
# Trained GMM for image 189
# Weights for GMM model 190: [0.85494351 0.06528336 0.03413267 0.04564046]
# Trained GMM for image 190
# Weights for GMM model 191: [0.83412258 0.07150617 0.05331261 0.04105865]
# Trained GMM for image 191
# Weights for GMM model 192: [0.85006901 0.06213269 0.04914023 0.03865807]
# Trained GMM for image 192
# Weights for GMM model 193: [0.81299027 0.06410228 0.04773001 0.07517744]
# Trained GMM for image 193
# Weights for GMM model 194: [0.83944844 0.06843188 0.0382573  0.05386239]
# Trained GMM for image 194
# Weights for GMM model 195: [0.82688838 0.07542577 0.03848397 0.05920187]
# Trained GMM for image 195
# Weights for GMM model 196: [0.84382483 0.06576737 0.03922474 0.05118305]
# Trained GMM for image 196
# Weights for GMM model 197: [0.0586037  0.81588743 0.0505738  0.07493507]
# Trained GMM for image 197
# Weights for GMM model 198: [0.80465215 0.0823702  0.06776637 0.04521128]
# Trained GMM for image 198
# Weights for GMM model 199: [0.81764783 0.06496519 0.07849012 0.03889686]
# Trained GMM for image 199
# Weights for GMM model 200: [0.83866731 0.05619639 0.03776744 0.06736886]
# Trained GMM for image 200
# Weights for GMM model 201: [0.82826457 0.06908545 0.06002634 0.04262364]
# Trained GMM for image 201
# Weights for GMM model 202: [0.82981638 0.06100921 0.0396362  0.06953822]
# Trained GMM for image 202
# Weights for GMM model 203: [0.07955494 0.81290139 0.06807905 0.03946462]
# Trained GMM for image 203
# Weights for GMM model 204: [0.02923332 0.85177026 0.05377822 0.0652182 ]
# Trained GMM for image 204
# Weights for GMM model 205: [0.80478413 0.07151645 0.04198771 0.08171171]
# Trained GMM for image 205
# Weights for GMM model 206: [0.83520946 0.07134287 0.03780968 0.05563799]
# Trained GMM for image 206
# Weights for GMM model 207: [0.05941769 0.81431984 0.08394025 0.04232223]
# Trained GMM for image 207
# Weights for GMM model 208: [0.83161787 0.07408429 0.06011217 0.03418567]
# Trained GMM for image 208
# Weights for GMM model 209: [0.8534141  0.06043926 0.04988846 0.03625818]
# Trained GMM for image 209
# Weights for GMM model 210: [0.83531873 0.07416588 0.03592288 0.05459251]
# Trained GMM for image 210
# Weights for GMM model 211: [0.79925905 0.08308175 0.07295104 0.04470816]
# Trained GMM for image 211
# Weights for GMM model 212: [0.83346021 0.05702588 0.07276589 0.03674801]
# Trained GMM for image 212
# Weights for GMM model 213: [0.80954366 0.0763538  0.07267498 0.04142756]
# Trained GMM for image 213
# Weights for GMM model 214: [0.82010444 0.0739348  0.04262021 0.06334055]
# Trained GMM for image 214
# Weights for GMM model 215: [0.07289497 0.83199565 0.03910739 0.05600199]
# Trained GMM for image 215
# Weights for GMM model 216: [0.82764559 0.07046465 0.04041175 0.06147801]
# Trained GMM for image 216
# Weights for GMM model 217: [0.84601681 0.06640448 0.05225453 0.03532418]
# Trained GMM for image 217
# Weights for GMM model 218: [0.82043256 0.07372993 0.04453882 0.06129869]
# Trained GMM for image 218
# Weights for GMM model 219: [0.79781892 0.07199848 0.08640737 0.04377523]
# Trained GMM for image 219
# Weights for GMM model 220: [0.8232852  0.06185828 0.04418712 0.07066941]
# Trained GMM for image 220
# Weights for GMM model 221: [0.84898142 0.06435174 0.05085151 0.03581532]
# Trained GMM for image 221
# Weights for GMM model 222: [0.85131448 0.06264793 0.03613471 0.04990288]
# Trained GMM for image 222
# Weights for GMM model 223: [0.03855939 0.06991164 0.06253349 0.82899547]
# Trained GMM for image 223
# Weights for GMM model 224: [0.80834867 0.06956289 0.07940037 0.04268806]
# Trained GMM for image 224
# Weights for GMM model 225: [0.80777911 0.0721235  0.0460883  0.07400908]
# Trained GMM for image 225
# Weights for GMM model 226: [0.83383254 0.0715834  0.03999582 0.05458825]
# Trained GMM for image 226
# Weights for GMM model 227: [0.85040052 0.05428857 0.0648899  0.03042101]
# Trained GMM for image 227
# Weights for GMM model 228: [0.83695167 0.05469481 0.0714813  0.03687222]
# Trained GMM for image 228
# Weights for GMM model 229: [0.05463019 0.83333955 0.06844582 0.04358444]
# Trained GMM for image 229
# Weights for GMM model 230: [0.8234727  0.06360725 0.04024059 0.07267946]
# Trained GMM for image 230
# Weights for GMM model 231: [0.84626396 0.05240725 0.03549596 0.06583284]
# Trained GMM for image 231
# Weights for GMM model 232: [0.85120457 0.05090074 0.03414462 0.06375007]
# Trained GMM for image 232
# Weights for GMM model 233: [0.83200218 0.06886515 0.05943189 0.03970078]
# Trained GMM for image 233
# Weights for GMM model 234: [0.84070054 0.05958543 0.06521643 0.03449759]
# Trained GMM for image 234
# Weights for GMM model 235: [0.83216449 0.06799834 0.05638639 0.04345078]
# Trained GMM for image 235
# Weights for GMM model 236: [0.83714265 0.06688666 0.03642836 0.05954233]
# Trained GMM for image 236
# Weights for GMM model 237: [0.81474461 0.0667031  0.03956475 0.07898754]
# Trained GMM for image 237
# Weights for GMM model 238: [0.82986285 0.07053432 0.03951897 0.06008386]
# Trained GMM for image 238
# Weights for GMM model 239: [0.85431491 0.05196828 0.06134778 0.03236904]
# Trained GMM for image 239
# Weights for GMM model 240: [0.82472362 0.06008303 0.03925919 0.07593415]
# Trained GMM for image 240
# Weights for GMM model 241: [0.86105073 0.05925011 0.03424259 0.04545657]
# Trained GMM for image 241
# Weights for GMM model 242: [0.06864905 0.83594478 0.03924718 0.05615898]
# Trained GMM for image 242
# Weights for GMM model 243: [0.81991535 0.07466287 0.03806738 0.06735441]
# Trained GMM for image 243
# Weights for GMM model 244: [0.03955201 0.06317021 0.83446901 0.06280878]
# Trained GMM for image 244
# Weights for GMM model 245: [0.82223573 0.07044559 0.04098694 0.06633175]
# Trained GMM for image 245
# Weights for GMM model 246: [0.82392063 0.0639369  0.0427137  0.06942877]
# Trained GMM for image 246
# Weights for GMM model 247: [0.78803907 0.07026753 0.09211093 0.04958248]
# Trained GMM for image 247
# Weights for GMM model 248: [0.84525236 0.06449438 0.03711598 0.05313729]
# Trained GMM for image 248
# Weights for GMM model 249: [0.84111574 0.0698948  0.05406065 0.03492882]
# Trained GMM for image 249
# Weights for GMM model 250: [0.82476604 0.06057294 0.07606237 0.03859865]
# Trained GMM for image 250
# Weights for GMM model 251: [0.82719206 0.07542732 0.03903935 0.05834126]
# Trained GMM for image 251
# Weights for GMM model 252: [0.82345725 0.07544561 0.0443564  0.05674074]
# Trained GMM for image 252
# Weights for GMM model 253: [0.06909407 0.81787424 0.04714526 0.06588643]
# Trained GMM for image 253
# Weights for GMM model 254: [0.82525805 0.06542611 0.03998638 0.06932946]
# Trained GMM for image 254
# Weights for GMM model 255: [0.07917721 0.81080905 0.07222238 0.03779136]
# Trained GMM for image 255
# Weights for GMM model 256: [0.08153647 0.79636184 0.04421341 0.07788828]
# Trained GMM for image 256
# Weights for GMM model 257: [0.84162638 0.05037912 0.03690594 0.07108856]
# Trained GMM for image 257
# Weights for GMM model 258: [0.84107398 0.06907074 0.03476409 0.05509118]
# Trained GMM for image 258
# Weights for GMM model 259: [0.83931838 0.06377178 0.05877548 0.03813437]
# Trained GMM for image 259
# Weights for GMM model 260: [0.82084444 0.07037896 0.04236927 0.06640732]
# Trained GMM for image 260
# Weights for GMM model 261: [0.7856137  0.09078067 0.07153611 0.05206952]
# Trained GMM for image 261
# Weights for GMM model 262: [0.77424167 0.09100471 0.05791867 0.07683494]
# Trained GMM for image 262
# Weights for GMM model 263: [0.85625279 0.05943135 0.05104305 0.0332728 ]
# Trained GMM for image 263
# Weights for GMM model 264: [0.82767114 0.07331701 0.05961614 0.03939571]
# Trained GMM for image 264
# Weights for GMM model 265: [0.82455599 0.07516369 0.04204778 0.05823254]
# Trained GMM for image 265
# Weights for GMM model 266: [0.84020831 0.06847322 0.04054335 0.05077511]
# Trained GMM for image 266
# Weights for GMM model 267: [0.84037586 0.05428833 0.0689445  0.03639131]
# Trained GMM for image 267
# Weights for GMM model 268: [0.04142121 0.81746612 0.07072354 0.07038913]
# Trained GMM for image 268
# Weights for GMM model 269: [0.04901882 0.84805049 0.06768215 0.03524854]
# Trained GMM for image 269
# Weights for GMM model 270: [0.82412176 0.06787069 0.03878972 0.06921784]
# Trained GMM for image 270
# Weights for GMM model 271: [0.80850085 0.07315586 0.04834292 0.07000036]
# Trained GMM for image 271
# Weights for GMM model 272: [0.81751041 0.07031811 0.07596787 0.03620361]
# Trained GMM for image 272
# Weights for GMM model 273: [0.8470736  0.05318261 0.03469452 0.06504927]
# Trained GMM for image 273
# Weights for GMM model 274: [0.81331556 0.07173445 0.0470054  0.06794459]
# Trained GMM for image 274
# Weights for GMM model 275: [0.83427255 0.07095033 0.03696609 0.05781103]
# Trained GMM for image 275
# Weights for GMM model 276: [0.83350351 0.07173497 0.05945645 0.03530506]
# Trained GMM for image 276
# Weights for GMM model 277: [0.79607534 0.08705438 0.06840622 0.04846407]
# Trained GMM for image 277
# Weights for GMM model 278: [0.82199106 0.03773652 0.06341147 0.07686095]
# Trained GMM for image 278
# Weights for GMM model 279: [0.80131689 0.07910142 0.04636991 0.07321177]
# Trained GMM for image 279
# Weights for GMM model 280: [0.82922343 0.07035146 0.05275629 0.04766882]
# Trained GMM for image 280
# Weights for GMM model 281: [0.82298385 0.08096231 0.05744995 0.03860389]
# Trained GMM for image 281
# Weights for GMM model 282: [0.05183159 0.85001467 0.06739786 0.03075588]
# Trained GMM for image 282
# Weights for GMM model 283: [0.84210217 0.06575978 0.0536517  0.03848635]
# Trained GMM for image 283
# Weights for GMM model 284: [0.83945666 0.05428889 0.03897199 0.06728246]
# Trained GMM for image 284
# Weights for GMM model 285: [0.04254822 0.82982571 0.05858382 0.06904225]
# Trained GMM for image 285
# Weights for GMM model 286: [0.85420958 0.05315776 0.0354414  0.05719126]
# Trained GMM for image 286
# Weights for GMM model 287: [0.82977961 0.06499772 0.05686175 0.04836092]
# Trained GMM for image 287
# Weights for GMM model 288: [0.82995918 0.06608074 0.04456329 0.05939679]
# Trained GMM for image 288
# Weights for GMM model 289: [0.86530858 0.04660262 0.0581937  0.0298951 ]
# Trained GMM for image 289
# Weights for GMM model 290: [0.80512498 0.07779006 0.07649391 0.04059105]
# Trained GMM for image 290
# Weights for GMM model 291: [0.85156906 0.06115192 0.04183282 0.0454462 ]
# Trained GMM for image 291
# Weights for GMM model 292: [0.80542984 0.06820282 0.07708448 0.04928285]
# Trained GMM for image 292
# Weights for GMM model 293: [0.8189144  0.06161481 0.06444992 0.05502088]
# Trained GMM for image 293
# Weights for GMM model 294: [0.81195744 0.07412422 0.04235977 0.07155856]
# Trained GMM for image 294
# Weights for GMM model 295: [0.81775896 0.06640427 0.04373924 0.07209753]
# Trained GMM for image 295
# Weights for GMM model 296: [0.82335902 0.06517428 0.04276915 0.06869755]
# Trained GMM for image 296
# Weights for GMM model 297: [0.82231584 0.07213827 0.05806829 0.0474776 ]
# Trained GMM for image 297
# Weights for GMM model 298: [0.80165173 0.08144236 0.04662764 0.07027827]
# Trained GMM for image 298
# Weights for GMM model 299: [0.07621516 0.80755535 0.06910979 0.04711971]
# Trained GMM for image 299
# Weights for GMM model 300: [0.83368371 0.0678392  0.04294762 0.05552947]
# Trained GMM for image 300
# Weights for GMM model 301: [0.032343   0.85663812 0.04907498 0.0619439 ]
# Trained GMM for image 301
# Weights for GMM model 302: [0.84231719 0.05737645 0.03611108 0.06419529]
# Trained GMM for image 302
# Weights for GMM model 303: [0.04704787 0.80844972 0.07482298 0.06967943]
# Trained GMM for image 303
# Weights for GMM model 304: [0.84081382 0.06002314 0.04135191 0.05781113]
# Trained GMM for image 304
# Weights for GMM model 305: [0.85047438 0.05521925 0.03540687 0.05889949]
# Trained GMM for image 305
# Weights for GMM model 306: [0.82608965 0.07106628 0.04042972 0.06241434]
# Trained GMM for image 306
# Weights for GMM model 307: [0.84986698 0.05544307 0.03787822 0.05681173]
# Trained GMM for image 307
# Weights for GMM model 308: [0.82993509 0.05830023 0.04626661 0.06549807]
# Trained GMM for image 308
# Weights for GMM model 309: [0.86593001 0.05941142 0.0453916  0.02926696]
# Trained GMM for image 309
# Weights for GMM model 310: [0.81885921 0.07093843 0.04948018 0.06072218]
# Trained GMM for image 310
# Weights for GMM model 311: [0.81456245 0.06395635 0.07022262 0.05125857]
# Trained GMM for image 311
# Weights for GMM model 312: [0.83278752 0.06475842 0.05285241 0.04960166]
# Trained GMM for image 312
# Weights for GMM model 313: [0.83414708 0.06378587 0.04676349 0.05530356]
# Trained GMM for image 313
# Weights for GMM model 314: [0.82671268 0.07068555 0.06156095 0.04104081]
# Trained GMM for image 314
# Weights for GMM model 315: [0.8329821  0.07027349 0.05612384 0.04062057]
# Trained GMM for image 315
# Weights for GMM model 316: [0.83618065 0.05860979 0.04035117 0.0648584 ]
# Trained GMM for image 316
# Weights for GMM model 317: [0.83676253 0.05650508 0.03919515 0.06753724]
# Trained GMM for image 317
# Weights for GMM model 318: [0.0745347  0.81036695 0.06824006 0.04685829]
# Trained GMM for image 318
# Weights for GMM model 319: [0.82821592 0.06651057 0.06369022 0.04158329]
# Trained GMM for image 319
# Weights for GMM model 320: [0.82432469 0.06294881 0.04233348 0.07039301]
# Trained GMM for image 320
# Weights for GMM model 321: [0.8087782  0.06858958 0.04565495 0.07697726]
# Trained GMM for image 321
# Weights for GMM model 322: [0.83668968 0.05470527 0.04056346 0.06804158]
# Trained GMM for image 322
# Weights for GMM model 323: [0.81245156 0.06683437 0.04746155 0.07325252]
# Trained GMM for image 323
# Weights for GMM model 324: [0.06070744 0.84995482 0.03833705 0.05100069]
# Trained GMM for image 324
# Weights for GMM model 325: [0.81065301 0.07069285 0.07076874 0.0478854 ]
# Trained GMM for image 325
# Weights for GMM model 326: [0.83980218 0.06706154 0.05345639 0.03967988]
# Trained GMM for image 326
# Weights for GMM model 327: [0.82385747 0.06954156 0.05876239 0.04783858]
# Trained GMM for image 327
# Weights for GMM model 328: [0.80576207 0.07261367 0.04536543 0.07625883]
# Trained GMM for image 328
# Weights for GMM model 329: [0.79493736 0.07671442 0.05370588 0.07464234]
# Trained GMM for image 329
# Weights for GMM model 330: [0.06134191 0.82442962 0.04210103 0.07212745]
# Trained GMM for image 330
# Weights for GMM model 331: [0.82094528 0.06878013 0.06492833 0.04534626]
# Trained GMM for image 331
# Weights for GMM model 332: [0.05203704 0.81444118 0.06761928 0.06590251]
# Trained GMM for image 332
# Weights for GMM model 333: [0.83335186 0.05924741 0.04253912 0.06486161]
# Trained GMM for image 333
# Weights for GMM model 334: [0.83191002 0.06849398 0.03953307 0.06006293]
# Trained GMM for image 334
# Weights for GMM model 335: [0.81693092 0.065891   0.07205007 0.045128  ]
# Trained GMM for image 335
# Weights for GMM model 336: [0.85470281 0.05026965 0.06132701 0.03370052]
# Trained GMM for image 336
# Weights for GMM model 337: [0.86517131 0.04633306 0.03054943 0.0579462 ]
# Trained GMM for image 337
# Weights for GMM model 338: [0.84221564 0.05246329 0.04188705 0.06343402]
# Trained GMM for image 338
# Weights for GMM model 339: [0.06629618 0.82795296 0.03999995 0.06575091]
# Trained GMM for image 339
# Weights for GMM model 340: [0.82333233 0.06640353 0.04593152 0.06433262]
# Trained GMM for image 340
# Weights for GMM model 341: [0.85222892 0.05274889 0.03633786 0.05868432]
# Trained GMM for image 341
# Weights for GMM model 342: [0.81921961 0.06535994 0.07162176 0.04379869]
# Trained GMM for image 342
# Weights for GMM model 343: [0.84196329 0.05997116 0.04929865 0.0487669 ]
# Trained GMM for image 343
# Weights for GMM model 344: [0.83865203 0.05523121 0.04750842 0.05860835]
# Trained GMM for image 344
# Weights for GMM model 345: [0.83766855 0.05607695 0.06234447 0.04391003]
# Trained GMM for image 345
# Weights for GMM model 346: [0.84862047 0.05994121 0.052409   0.03902932]
# Trained GMM for image 346
# Weights for GMM model 347: [0.84764891 0.06227642 0.04886138 0.0412133 ]
# Trained GMM for image 347
# Weights for GMM model 348: [0.0412964  0.83626498 0.06125495 0.06118367]
# Trained GMM for image 348
# Weights for GMM model 349: [0.84499628 0.06485231 0.05707082 0.03308059]
# Trained GMM for image 349
# Weights for GMM model 350: [0.81297857 0.07161811 0.04274033 0.07266299]
# Trained GMM for image 350
# Weights for GMM model 351: [0.83609781 0.05697972 0.06333309 0.04358939]
# Trained GMM for image 351
# Weights for GMM model 352: [0.83837795 0.05427653 0.03776533 0.06958019]
# Trained GMM for image 352
# Weights for GMM model 353: [0.81799647 0.06901875 0.04763195 0.06535283]
# Trained GMM for image 353
# Weights for GMM model 354: [0.83767307 0.06107376 0.03842535 0.06282782]
# Trained GMM for image 354
# Weights for GMM model 355: [0.79108573 0.07472284 0.08028321 0.05390822]
# Trained GMM for image 355
# Weights for GMM model 356: [0.84616198 0.05170921 0.06539538 0.03673343]
# Trained GMM for image 356
# Weights for GMM model 357: [0.83106109 0.06636138 0.04730444 0.0552731 ]
# Trained GMM for image 357
# Weights for GMM model 358: [0.80904018 0.07049222 0.04729455 0.07317305]
# Trained GMM for image 358
# Weights for GMM model 359: [0.84333487 0.06116887 0.03972878 0.05576749]
# Trained GMM for image 359
# Weights for GMM model 360: [0.83262336 0.06107987 0.03666033 0.06963644]
# Trained GMM for image 360
# Weights for GMM model 361: [0.82095649 0.06490805 0.04105847 0.07307699]
# Trained GMM for image 361
# Weights for GMM model 362: [0.83849114 0.06386841 0.04428599 0.05335446]
# Trained GMM for image 362
# Weights for GMM model 363: [0.85031604 0.04746862 0.06238015 0.03983519]
# Trained GMM for image 363
# Weights for GMM model 364: [0.81764319 0.06724707 0.0692411  0.04586864]
# Trained GMM for image 364
# Weights for GMM model 365: [0.82745979 0.05934585 0.04178846 0.07140591]
# Trained GMM for image 365
# Weights for GMM model 366: [0.84855191 0.0572193  0.06040144 0.03382735]
# Trained GMM for image 366
# Weights for GMM model 367: [0.82484948 0.06039375 0.06257408 0.0521827 ]
# Trained GMM for image 367
# Weights for GMM model 368: [0.84961001 0.05940467 0.03578714 0.05519818]
# Trained GMM for image 368
# Weights for GMM model 369: [0.82685914 0.06148967 0.04572859 0.0659226 ]
# Trained GMM for image 369
# Weights for GMM model 370: [0.03917253 0.84489844 0.05392165 0.06200738]
# Trained GMM for image 370
# Weights for GMM model 371: [0.06852185 0.80983075 0.05029508 0.07135231]
# Trained GMM for image 371
# Weights for GMM model 372: [0.82638107 0.06274836 0.04880907 0.06206149]
# Trained GMM for image 372
# Weights for GMM model 373: [0.82112808 0.06137422 0.05368076 0.06381694]
# Trained GMM for image 373
# Weights for GMM model 374: [0.85298495 0.05380758 0.05014304 0.04306443]
# Trained GMM for image 374
# Weights for GMM model 375: [0.83321969 0.05955328 0.04646534 0.06076169]
# Trained GMM for image 375
# Weights for GMM model 376: [0.83600284 0.05920714 0.04982052 0.05496951]
# Trained GMM for image 376
# Weights for GMM model 377: [0.06492372 0.83458877 0.04763284 0.05285468]
# Trained GMM for image 377
# Weights for GMM model 378: [0.82225867 0.06860559 0.04305788 0.06607785]
# Trained GMM for image 378
# Weights for GMM model 379: [0.82035389 0.07180739 0.04539464 0.06244407]
# Trained GMM for image 379
# Weights for GMM model 380: [0.84740551 0.06120186 0.04117428 0.05021835]
# Trained GMM for image 380
# Weights for GMM model 381: [0.81638539 0.07176842 0.05339791 0.05844828]
# Trained GMM for image 381
# Weights for GMM model 382: [0.83893739 0.06107021 0.04384661 0.05614579]
# Trained GMM for image 382
# Weights for GMM model 383: [0.81863904 0.06683732 0.0477401  0.06678354]
# Trained GMM for image 383
# Weights for GMM model 384: [0.86259796 0.04721551 0.04866629 0.04152025]
# Trained GMM for image 384
# Weights for GMM model 385: [0.80827862 0.07123765 0.05500164 0.06548209]
# Trained GMM for image 385
# Weights for GMM model 386: [0.84281726 0.06490184 0.05063232 0.04164858]
# Trained GMM for image 386
# Weights for GMM model 387: [0.84885841 0.05396032 0.03980763 0.05737364]
# Trained GMM for image 387
# Weights for GMM model 388: [0.04270768 0.82992525 0.06231009 0.06505698]
# Trained GMM for image 388
# Weights for GMM model 389: [0.83996406 0.05557837 0.04146926 0.06298831]
# Trained GMM for image 389
# Weights for GMM model 390: [0.84026448 0.05978832 0.06137274 0.03857446]
# Trained GMM for image 390
# Weights for GMM model 391: [0.82732894 0.06720576 0.06023691 0.04522839]
# Trained GMM for image 391
# Weights for GMM model 392: [0.85381782 0.05646844 0.04088371 0.04883003]
# Trained GMM for image 392
# Weights for GMM model 393: [0.85123256 0.05040084 0.04277083 0.05559577]
# Trained GMM for image 393
# Weights for GMM model 394: [0.8540967  0.05718666 0.03467431 0.05404233]
# Trained GMM for image 394
# Weights for GMM model 395: [0.83689874 0.06154821 0.05614883 0.04540422]
# Trained GMM for image 395
# Weights for GMM model 396: [0.81504718 0.06066286 0.05848117 0.06580878]
# Trained GMM for image 396
# Weights for GMM model 397: [0.83555087 0.05443454 0.05948982 0.05052477]
# Trained GMM for image 397
# Weights for GMM model 398: [0.83674643 0.06510068 0.04789124 0.05026165]
# Trained GMM for image 398
# Weights for GMM model 399: [0.82934745 0.06108297 0.05185549 0.05771409]
# Trained GMM for image 399
# Weights for GMM model 400: [0.81838243 0.06071231 0.05410128 0.06680397]
# Trained GMM for image 400
# Weights for GMM model 401: [0.83778833 0.06658657 0.05822171 0.03740339]
# Trained GMM for image 401
# Weights for GMM model 402: [0.844325   0.05560364 0.04264018 0.05743118]
# Trained GMM for image 402
# Weights for GMM model 403: [0.85287177 0.05465755 0.04254497 0.0499257 ]
# Trained GMM for image 403
# Weights for GMM model 404: [0.06256846 0.84925107 0.04714789 0.04103258]
# Trained GMM for image 404
# Weights for GMM model 405: [0.79800405 0.06797635 0.0533054  0.08071421]
# Trained GMM for image 405
# Weights for GMM model 406: [0.82761555 0.06499795 0.04875594 0.05863055]
# Trained GMM for image 406
# Weights for GMM model 407: [0.81547389 0.06203683 0.06759011 0.05489917]
# Trained GMM for image 407
# Weights for GMM model 408: [0.8153625  0.06280317 0.07257673 0.0492576 ]
# Trained GMM for image 408
# Weights for GMM model 409: [0.82147156 0.05915882 0.05371949 0.06565013]
# Trained GMM for image 409
# Weights for GMM model 410: [0.05748333 0.8548991  0.03975859 0.04785898]
# Trained GMM for image 410
# Weights for GMM model 411: [0.04958406 0.86052383 0.03685363 0.05303848]
# Trained GMM for image 411
# Weights for GMM model 412: [0.856527   0.05542048 0.04151964 0.04653288]
# Trained GMM for image 412
# Weights for GMM model 413: [0.84711543 0.06080277 0.04078652 0.05129528]
# Trained GMM for image 413
# Weights for GMM model 414: [0.844417   0.06107695 0.03889803 0.05560802]
# Trained GMM for image 414
# Weights for GMM model 415: [0.8345537  0.06032349 0.06852721 0.0365956 ]
# Trained GMM for image 415
# Weights for GMM model 416: [0.84088208 0.06272337 0.05115481 0.04523974]
# Trained GMM for image 416
# Weights for GMM model 417: [0.83896907 0.05720389 0.04926034 0.0545667 ]
# Trained GMM for image 417
# Weights for GMM model 418: [0.82323611 0.04356934 0.08846611 0.04472844]
# Trained GMM for image 418
# Weights for GMM model 419: [0.82954525 0.06349611 0.04782123 0.05913742]
# Trained GMM for image 419
# Weights for GMM model 420: [0.78016668 0.07129419 0.06264678 0.08589234]
# Trained GMM for image 420
# Weights for GMM model 421: [0.82069011 0.06010279 0.05211049 0.06709661]
# Trained GMM for image 421
# Weights for GMM model 422: [0.07039914 0.82953349 0.04224523 0.05782215]
# Trained GMM for image 422
# Weights for GMM model 423: [0.81604923 0.06143752 0.06210983 0.06040342]
# Trained GMM for image 423
# Weights for GMM model 424: [0.86783161 0.05129857 0.03901867 0.04185115]
# Trained GMM for image 424
# Weights for GMM model 425: [0.82356299 0.05603331 0.06490165 0.05550204]
# Trained GMM for image 425
# Weights for GMM model 426: [0.8564924  0.05237321 0.03538059 0.0557538 ]
# Trained GMM for image 426
# Weights for GMM model 427: [0.80507708 0.06296173 0.05757788 0.07438331]
# Trained GMM for image 427
# Weights for GMM model 428: [0.83737379 0.06323006 0.06482141 0.03457474]
# Trained GMM for image 428
# Weights for GMM model 429: [0.85604039 0.04841057 0.0341402  0.06140884]
# Trained GMM for image 429
# Weights for GMM model 430: [0.05983512 0.82798697 0.06198629 0.05019163]
# Trained GMM for image 430
# Weights for GMM model 431: [0.84920701 0.05205349 0.03876809 0.05997141]
# Trained GMM for image 431
# Weights for GMM model 432: [0.82458115 0.05893236 0.05523005 0.06125644]
# Trained GMM for image 432
# Weights for GMM model 433: [0.85445232 0.05654024 0.03469938 0.05430806]
# Trained GMM for image 433
# Weights for GMM model 434: [0.82318516 0.06358509 0.05136511 0.06186464]
# Trained GMM for image 434
# Weights for GMM model 435: [0.83514003 0.05485106 0.04638312 0.06362579]
# Trained GMM for image 435
# Weights for GMM model 436: [0.80573949 0.07154524 0.05544717 0.0672681 ]
# Trained GMM for image 436
# Weights for GMM model 437: [0.82258703 0.06298779 0.063864   0.05056118]
# Trained GMM for image 437
# Weights for GMM model 438: [0.84652385 0.04496407 0.04864899 0.05986308]
# Trained GMM for image 438
# Weights for GMM model 439: [0.85302801 0.05534225 0.04690818 0.04472156]
# Trained GMM for image 439
# Weights for GMM model 440: [0.06971748 0.81837265 0.05889477 0.0530151 ]
# Trained GMM for image 440
# Weights for GMM model 441: [0.82938566 0.06421364 0.06156703 0.04483366]
# Trained GMM for image 441
# Weights for GMM model 442: [0.81550536 0.06327626 0.05107623 0.07014215]
# Trained GMM for image 442
# Weights for GMM model 443: [0.03801499 0.85596159 0.05459572 0.05142771]
# Trained GMM for image 443
# Weights for GMM model 444: [0.82077876 0.06447135 0.05023748 0.06451241]
# Trained GMM for image 444
# Weights for GMM model 445: [0.78722455 0.06549631 0.06922457 0.07805457]
# Trained GMM for image 445
# Weights for GMM model 446: [0.85394322 0.05023238 0.05222799 0.04359641]
# Trained GMM for image 446
# Weights for GMM model 447: [0.79305311 0.07601443 0.07242905 0.05850342]
# Trained GMM for image 447
# Weights for GMM model 448: [0.81903976 0.05527782 0.06910422 0.05657821]
# Trained GMM for image 448
# Weights for GMM model 449: [0.81629558 0.06279674 0.05555671 0.06535096]
# Trained GMM for image 449
# Weights for GMM model 450: [0.80290869 0.0619533  0.05922796 0.07591005]
# Trained GMM for image 450
# Weights for GMM model 451: [0.806208   0.07168371 0.06752096 0.05458734]
# Trained GMM for image 451
# Weights for GMM model 452: [0.8353408  0.05918649 0.06350094 0.04197176]
# Trained GMM for image 452
# Weights for GMM model 453: [0.85322107 0.04821718 0.04981242 0.04874933]
# Trained GMM for image 453
# Weights for GMM model 454: [0.81810262 0.06744306 0.04730246 0.06715186]
# Trained GMM for image 454
# Weights for GMM model 455: [0.83901951 0.05820968 0.04751448 0.05525633]
# Trained GMM for image 455
# Weights for GMM model 456: [0.81424359 0.05818047 0.07049467 0.05708127]
# Trained GMM for image 456
# Weights for GMM model 457: [0.77672221 0.08193931 0.06990605 0.07143242]
# Trained GMM for image 457
# Weights for GMM model 458: [0.82947361 0.05557755 0.0598248  0.05512404]
# Trained GMM for image 458
# Weights for GMM model 459: [0.85081788 0.04835065 0.04268161 0.05814986]
# Trained GMM for image 459
# Weights for GMM model 460: [0.81624308 0.06404362 0.05719877 0.06251453]
# Trained GMM for image 460
# Weights for GMM model 461: [0.84981346 0.05519252 0.04909935 0.04589467]
# Trained GMM for image 461
# Weights for GMM model 462: [0.06550345 0.81040746 0.05107857 0.07301052]
# Trained GMM for image 462
# Weights for GMM model 463: [0.81834031 0.06065122 0.0602922  0.06071627]
# Trained GMM for image 463
# Weights for GMM model 464: [0.8182411  0.06084277 0.05306676 0.06784936]
# Trained GMM for image 464
# Weights for GMM model 465: [0.84288851 0.05546546 0.0477506  0.05389544]
# Trained GMM for image 465
# Weights for GMM model 466: [0.81625497 0.05738894 0.06482557 0.06153052]
# Trained GMM for image 466
# Weights for GMM model 467: [0.0561742  0.84455493 0.04683508 0.05243579]
# Trained GMM for image 467
# Weights for GMM model 468: [0.82174771 0.06217183 0.05850481 0.05757566]
# Trained GMM for image 468
# Weights for GMM model 469: [0.04475543 0.80914431 0.06424801 0.08185226]
# Trained GMM for image 469
# Weights for GMM model 470: [0.06224354 0.8152924  0.06152819 0.06093586]
# Trained GMM for image 470
# Weights for GMM model 471: [0.8549605  0.05161329 0.05276135 0.04066487]
# Trained GMM for image 471
# Weights for GMM model 472: [0.81171356 0.06152387 0.05827964 0.06848293]
# Trained GMM for image 472
# Weights for GMM model 473: [0.82550487 0.064189   0.06337625 0.04692988]
# Trained GMM for image 473
# Weights for GMM model 474: [0.83248693 0.05091418 0.05203982 0.06455907]
# Trained GMM for image 474
# Weights for GMM model 475: [0.05495071 0.83602926 0.05921164 0.04980838]
# Trained GMM for image 475
# Weights for GMM model 476: [0.84534859 0.05963937 0.04762947 0.04738258]
# Trained GMM for image 476
# Weights for GMM model 477: [0.84363622 0.05404936 0.04591464 0.05639977]
# Trained GMM for image 477
# Weights for GMM model 478: [0.05482102 0.84965652 0.04492356 0.05059889]
# Trained GMM for image 478
# Weights for GMM model 479: [0.83556953 0.0579353  0.06080114 0.04569404]
# Trained GMM for image 479
# Weights for GMM model 480: [0.82475903 0.0583392  0.0505424  0.06635937]
# Trained GMM for image 480
# Weights for GMM model 481: [0.82934638 0.05503599 0.05235267 0.06326496]
# Trained GMM for image 481
# Weights for GMM model 482: [0.81907585 0.06190856 0.0507945  0.06822108]
# Trained GMM for image 482
# Weights for GMM model 483: [0.84148377 0.05949435 0.05461146 0.04441042]
# Trained GMM for image 483
# Weights for GMM model 484: [0.82424297 0.06454806 0.05689013 0.05431883]
# Trained GMM for image 484
# Weights for GMM model 485: [0.82647343 0.06756507 0.05320963 0.05275187]
# Trained GMM for image 485
# Weights for GMM model 486: [0.82647796 0.06139342 0.05693626 0.05519236]
# Trained GMM for image 486
# Weights for GMM model 487: [0.07174164 0.83136177 0.04964553 0.04725106]
# Trained GMM for image 487
# Weights for GMM model 488: [0.80983387 0.06481482 0.06820207 0.05714925]
# Trained GMM for image 488
# Weights for GMM model 489: [0.84680203 0.05530927 0.04433954 0.05354916]
# Trained GMM for image 489
# Weights for GMM model 490: [0.06122311 0.82976092 0.05739442 0.05162155]
# Trained GMM for image 490
# Weights for GMM model 491: [0.0651967  0.83672128 0.04694395 0.05113806]
# Trained GMM for image 491
# Weights for GMM model 492: [0.83199416 0.06505814 0.03947585 0.06347185]
# Trained GMM for image 492
# Weights for GMM model 493: [0.81020997 0.06454093 0.05260603 0.07264307]
# Trained GMM for image 493
# Weights for GMM model 494: [0.83009516 0.06919437 0.03968568 0.0610248 ]
# Trained GMM for image 494
# Weights for GMM model 495: [0.82406165 0.07243537 0.051699   0.05180398]
# Trained GMM for image 495
# Weights for GMM model 496: [0.83245609 0.05825026 0.04673651 0.06255713]
# Trained GMM for image 496
# Weights for GMM model 497: [0.86191218 0.04397488 0.05657554 0.0375374 ]
# Trained GMM for image 497
# Weights for GMM model 498: [0.05206187 0.84902988 0.05728956 0.04161869]
# Trained GMM for image 498
# Weights for GMM model 499: [0.82612146 0.06466985 0.0511216  0.05808708]
# Trained GMM for image 499
# Weights for GMM model 500: [0.81093211 0.07779326 0.05359572 0.05767892]
# Trained GMM for image 500
# Weights for GMM model 501: [0.82207806 0.06064681 0.05608776 0.06118736]
# Trained GMM for image 501
# Weights for GMM model 502: [0.04309373 0.84717919 0.05201021 0.05771686]
# Trained GMM for image 502
# Weights for GMM model 503: [0.82820433 0.05904485 0.06103035 0.05172047]
# Trained GMM for image 503
# Weights for GMM model 504: [0.81900847 0.06165415 0.0532862  0.06605118]
# Trained GMM for image 504
# Weights for GMM model 505: [0.85502777 0.0466297  0.0400336  0.05830893]
# Trained GMM for image 505
# Weights for GMM model 506: [0.82248793 0.05911903 0.0543181  0.06407494]
# Trained GMM for image 506
# Weights for GMM model 507: [0.82995553 0.06563274 0.04950156 0.05491016]
# Trained GMM for image 507
# Weights for GMM model 508: [0.84349016 0.053577   0.04082773 0.0621051 ]
# Trained GMM for image 508
# Weights for GMM model 509: [0.83649218 0.0522436  0.0472063  0.06405792]
# Trained GMM for image 509
# Weights for GMM model 510: [0.83953868 0.05865566 0.04641054 0.05539511]
# Trained GMM for image 510
# Weights for GMM model 511: [0.83033833 0.05291219 0.04930901 0.06744046]
# Trained GMM for image 511
# Weights for GMM model 512: [0.83107176 0.0648627  0.04921438 0.05485116]
# Trained GMM for image 512
# Weights for GMM model 513: [0.82167055 0.06631793 0.057455   0.05455651]
# Trained GMM for image 513
# Weights for GMM model 514: [0.8427201  0.05191705 0.04155741 0.06380544]
# Trained GMM for image 514
# Weights for GMM model 515: [0.82499873 0.06913611 0.04989873 0.05596643]
# Trained GMM for image 515
# Weights for GMM model 516: [0.82585926 0.06288964 0.04326145 0.06798964]
# Trained GMM for image 516
# Weights for GMM model 517: [0.81885839 0.07089131 0.05056563 0.05968467]
# Trained GMM for image 517
# Weights for GMM model 518: [0.83292245 0.05954597 0.05322623 0.05430535]
# Trained GMM for image 518
# Weights for GMM model 519: [0.82646816 0.05251904 0.06519093 0.05582187]
# Trained GMM for image 519
# Weights for GMM model 520: [0.06640028 0.82410674 0.04947717 0.06001581]
# Trained GMM for image 520
# Weights for GMM model 521: [0.83245309 0.06311724 0.05009366 0.054336  ]
# Trained GMM for image 521
# okey

# %%
original_shape = load_nii(train_files[0]).shape # image_shape 98,116,94

def models_prediction(image_files, model, images):
    segmented_image = []
    for i in range(len(images)):
        gmm_labels = model.predict(image_files[i])
        segmented_image.append(reconstruct_images(gmm_labels, original_shape))
    return segmented_image

count = 0
best_segmented_images = 0
for i in range(len(train_files)):
    segmented_image = prediction(flatted_test_images, gmm_models[i], test_images)
    results = get_best_and_worst_ids(segmented_image)
    print("model : ", i)
    print("best: ", results['best_performance'] , " worst:" , results['worst_performance'])
    print("----------------------------------")
    if (results['best_performance'] + results['worst_performance'] > count):
        count = results['best_performance'] + results['worst_performance']
        best_segmented_images = segmented_image

segmented_test_images = best_segmented_images

pred_seg_2 = segmented_test_images

# ----------------------------------- END -------------------------------------
# Out:
# finish prediction
# model :  0
# best:  0.514201178208926  worst: 0.28983635353746334
# ----------------------------------
# finish prediction
# model :  1
# best:  0.7641499285190736  worst: 0.24597780150066653
# ----------------------------------
# finish prediction
# model :  2
# best:  0.23950500722638005  worst: 0.03014182832789767
# ----------------------------------
# finish prediction
# model :  3
# best:  0.6883854516332815  worst: 0.2508700352867427
# ----------------------------------
# finish prediction
# model :  4
# best:  0.7606731794122336  worst: 0.2460513425492293
# ----------------------------------
# finish prediction
# model :  5
# best:  0.6479086988077789  worst: 0.2513680273011079
# ----------------------------------
# finish prediction
# model :  6
# best:  0.5336016978854031  worst: 0.2945399368437559
# ----------------------------------
# finish prediction
# model :  7
# best:  0.3385837785690384  worst: 0.0037091398912936354
# ----------------------------------
# finish prediction
# model :  8
# best:  0.5046013502863794  worst: 0.3156660043832442
# ----------------------------------
# finish prediction
# model :  9
# best:  0.7662261295631898  worst: 0.2461606240086799
# ----------------------------------
# finish prediction
# model :  10
# best:  0.49868273998591217  worst: 0.3207086446597754
# ----------------------------------
# finish prediction
# model :  11
# best:  0.7604972384307694  worst: 0.24615317712480644
# ----------------------------------
# finish prediction
# model :  12
# best:  0.4675008632800932  worst: 0.2705677564581507
# ----------------------------------
# finish prediction
# model :  13
# best:  0.3296966636836074  worst: 0.0037045780866196325
# ----------------------------------
# finish prediction
# model :  14
# best:  0.5067099166944261  worst: 0.3050898070153043
# ----------------------------------
# finish prediction
# model :  15
# best:  0.7689526185458987  worst: 0.2460326336067826
# ----------------------------------
# finish prediction
# model :  16
# best:  0.7668340304833282  worst: 0.24600697467200222
# ----------------------------------
# finish prediction
# model :  17
# best:  0.5137896296707118  worst: 0.2892231564974735
# ----------------------------------
# finish prediction
# model :  18
# best:  0.532991974039933  worst: 0.24961263084543225
# ----------------------------------
# finish prediction
# model :  19
# best:  0.7623584569526122  worst: 0.24633950404410665
# ----------------------------------
# finish prediction
# model :  20
# best:  0.5774258432071517  worst: 0.25030779261597363
# ----------------------------------
# finish prediction
# model :  21
# best:  0.4952159589422601  worst: 0.30966309588786045
# ----------------------------------
# finish prediction
# model :  22
# best:  0.4777903311668251  worst: 0.27320749129762906
# ----------------------------------
# finish prediction
# model :  23
# best:  0.4966487122960886  worst: 0.37409041106390206
# ----------------------------------
# finish prediction
# model :  24
# best:  0.6281133129115268  worst: 0.2509639001364401
# ----------------------------------
# finish prediction
# model :  25
# best:  0.5127933069780709  worst: 0.2956381414921973
# ----------------------------------
# finish prediction
# model :  26
# best:  0.7896155310588411  worst: 0.2465676954117651
# ----------------------------------
# finish prediction
# model :  27
# best:  0.5102592660554931  worst: 0.2976275186812205
# ----------------------------------
# finish prediction
# model :  28
# best:  0.7619813241931697  worst: 0.24621597869758458
# ----------------------------------
# finish prediction
# model :  29
# best:  0.43551994510915953  worst: 0.24538424227688138
# ----------------------------------
# finish prediction
# model :  30
# best:  0.23666844851118013  worst: 0.038536076928670907
# ----------------------------------
# finish prediction
# model :  31
# best:  0.6850536974386787  worst: 0.25081509150198356
# ----------------------------------
# finish prediction
# model :  32
# best:  0.4777428162277859  worst: 0.27161324112788515
# ----------------------------------
# finish prediction
# model :  33
# best:  0.7715705942794737  worst: 0.2605915301628634
# ----------------------------------
# finish prediction
# model :  34
# best:  0.7781673743456919  worst: 0.2567945601358718
# ----------------------------------
# finish prediction
# model :  35
# best:  0.6701843869928547  worst: 0.24546559260503217
# ----------------------------------
# finish prediction
# model :  36
# best:  0.4804673597509539  worst: 0.2934362663711805
# ----------------------------------
# finish prediction
# model :  37
# best:  0.2274416136144969  worst: 0.03625943439176871
# ----------------------------------
# finish prediction
# model :  38
# best:  0.7876959914754423  worst: 0.24679860948159837
# ----------------------------------
# finish prediction
# model :  39
# best:  0.5978913591300875  worst: 0.4191431431352345
# ----------------------------------
# finish prediction
# model :  40
# best:  0.5047004718347665  worst: 0.28386152761812267
# ----------------------------------
# finish prediction
# model :  41
# best:  0.67659480500236  worst: 0.2514468165241999
# ----------------------------------
# finish prediction
# model :  42
# best:  0.5912760507273683  worst: 0.2455609427609792
# ----------------------------------
# finish prediction
# model :  43
# best:  0.49284174365620176  worst: 0.29939725289157015
# ----------------------------------
# finish prediction
# model :  44
# best:  0.48332554110186526  worst: 0.3363625858404407
# ----------------------------------
# finish prediction
# model :  45
# best:  0.7723351487482955  worst: 0.24658955152723652
# ----------------------------------
# finish prediction
# model :  46
# best:  0.5544323256430292  worst: 0.24994672008630225
# ----------------------------------
# finish prediction
# model :  47
# best:  0.4295187762065022  worst: 0.00554440965892846
# ----------------------------------
# finish prediction
# model :  48
# best:  0.5210364130576175  worst: 0.3649465010183452
# ----------------------------------
# finish prediction
# model :  49
# best:  0.5051663312787273  worst: 0.306993231989639
# ----------------------------------
# finish prediction
# model :  50
# best:  0.41913104827863423  worst: 0.005676599374317817
# ----------------------------------
# finish prediction
# model :  51
# best:  0.7618385223640392  worst: 0.2461423361609108
# ----------------------------------
# finish prediction
# model :  52
# best:  0.7687412301975335  worst: 0.24598995874150098
# ----------------------------------
# finish prediction
# model :  53
# best:  0.5251955155777746  worst: 0.2899363788898202
# ----------------------------------
# finish prediction
# model :  54
# best:  0.5131138216329212  worst: 0.38599985402847975
# ----------------------------------
# finish prediction
# model :  55
# best:  0.6209244189921511  worst: 0.24543825552653067
# ----------------------------------
# finish prediction
# model :  56
# best:  0.4951926170267561  worst: 0.24846408841105752
# ----------------------------------
# finish prediction
# model :  57
# best:  0.5259062951753253  worst: 0.24885014759055132
# ----------------------------------
# finish prediction
# model :  58
# best:  0.5086200003714745  worst: 0.30150019426209534
# ----------------------------------
# finish prediction
# model :  59
# best:  0.5067338861038541  worst: 0.24848690515739172
# ----------------------------------
# finish prediction
# model :  60
# best:  0.7700171241101625  worst: 0.24603547895919292
# ----------------------------------
# finish prediction
# model :  61
# best:  0.5211923323856814  worst: 0.3786756250158654
# ----------------------------------
# finish prediction
# model :  62
# best:  0.7772997200167207  worst: 0.24617176727553303
# ----------------------------------
# finish prediction
# model :  63
# best:  0.5152855553125528  worst: 0.248528067093755
# ----------------------------------
# finish prediction
# model :  64
# best:  0.5123579366462561  worst: 0.3006468663976441
# ----------------------------------
# finish prediction
# model :  65
# best:  0.2299835263485802  worst: 0.003293432705893598
# ----------------------------------
# finish prediction
# model :  66
# best:  0.41935172795556275  worst: 0.005512894373316661
# ----------------------------------
# finish prediction
# model :  67
# best:  0.4257500310915635  worst: 0.24538357972208738
# ----------------------------------
# finish prediction
# model :  68
# best:  0.5112869758442857  worst: 0.2947191714106393
# ----------------------------------
# finish prediction
# model :  69
# best:  0.47823593455881275  worst: 0.054819346542717765
# ----------------------------------
# finish prediction
# model :  70
# best:  0.42388857330107876  worst: 0.00997722115194057
# ----------------------------------
# finish prediction
# model :  71
# best:  0.5160375609419208  worst: 0.2874385179079796
# ----------------------------------
# finish prediction
# model :  72
# best:  0.36151108923742686  worst: 0.0037106774598532
# ----------------------------------
# finish prediction
# model :  73
# best:  0.6468596727647546  worst: 0.24543497425882985
# ----------------------------------
# finish prediction
# model :  74
# best:  0.5440367614374955  worst: 0.4018381051536396
# ----------------------------------
# finish prediction
# model :  75
# best:  0.5251838905528274  worst: 0.31050000395469796
# ----------------------------------
# finish prediction
# model :  76
# best:  0.2352712624260661  worst: 0.03824879689201332
# ----------------------------------
# finish prediction
# model :  77
# best:  0.5200632788565136  worst: 0.3622879394547185
# ----------------------------------
# finish prediction
# model :  78
# best:  0.23039279517967692  worst: 0.03160184289625585
# ----------------------------------
# finish prediction
# model :  79
# best:  0.5113445690367943  worst: 0.29901388045396454
# ----------------------------------
# finish prediction
# model :  80
# best:  0.48927532620498104  worst: 0.2780182771968607
# ----------------------------------
# finish prediction
# model :  81
# best:  0.26503347081623296  worst: 0.14085346911305682
# ----------------------------------
# finish prediction
# model :  82
# best:  0.23589188213333154  worst: 0.02943108914395363
# ----------------------------------
# finish prediction
# model :  83
# best:  0.5280594249544273  worst: 0.300338541040515
# ----------------------------------
# finish prediction
# model :  84
# best:  0.5197100460878535  worst: 0.3588658505781432
# ----------------------------------
# finish prediction
# model :  85
# best:  0.4440372034359187  worst: 0.2484973229848254
# ----------------------------------
# finish prediction
# model :  86
# best:  0.24132678216646494  worst: 0.060066364740551575
# ----------------------------------
# finish prediction
# model :  87
# best:  0.5045375479164702  worst: 0.28441757773860643
# ----------------------------------
# finish prediction
# model :  88
# best:  0.7683918924902822  worst: 0.24597151811604562
# ----------------------------------
# finish prediction
# model :  89
# best:  0.5296599550585617  worst: 0.3991463393344521
# ----------------------------------
# finish prediction
# model :  90
# best:  0.5174709077626487  worst: 0.37601818688599004
# ----------------------------------
# finish prediction
# model :  91
# best:  0.5092849505275817  worst: 0.2485675634983282
# ----------------------------------
# finish prediction
# model :  92
# best:  0.7671249286480876  worst: 0.24619562491856112
# ----------------------------------
# finish prediction
# model :  93
# best:  0.5142094482796442  worst: 0.2886721402277737
# ----------------------------------
# finish prediction
# model :  94
# best:  0.3115205288225486  worst: 0.003708547955146026
# ----------------------------------
# finish prediction
# model :  95
# best:  0.772870942514607  worst: 0.24655810418627336
# ----------------------------------
# finish prediction
# model :  96
# best:  0.7879654975719155  worst: 0.2477261892449998
# ----------------------------------
# finish prediction
# model :  97
# best:  0.23610534361660526  worst: 0.036533881853743996
# ----------------------------------
# finish prediction
# model :  98
# best:  0.23728898048398864  worst: 0.02731042947756293
# ----------------------------------
# finish prediction
# model :  99
# best:  0.7838981199326942  worst: 0.24636823411114045
# ----------------------------------
# finish prediction
# model :  100
# best:  0.5159963663591912  worst: 0.28990285260750587
# ----------------------------------
# finish prediction
# model :  101
# best:  0.7510050249170958  worst: 0.24591640518281963
# ----------------------------------
# finish prediction
# model :  102
# best:  0.2514746164243088  worst: 0.03593757420130478
# ----------------------------------
# finish prediction
# model :  103
# best:  0.5204691229097734  worst: 0.3718299544483463
# ----------------------------------
# finish prediction
# model :  104
# best:  0.7874532615643131  worst: 0.24639867118657868
# ----------------------------------
# finish prediction
# model :  105
# best:  0.27231388770745296  worst: 0.10440037902721269
# ----------------------------------
# finish prediction
# model :  106
# best:  0.7585220686093344  worst: 0.2460954496622498
# ----------------------------------
# finish prediction
# model :  107
# best:  0.6733335918684679  worst: 0.26146620185888875
# ----------------------------------
# finish prediction
# model :  108
# best:  0.728215045408384  worst: 0.2456273984347573
# ----------------------------------
# finish prediction
# model :  109
# best:  0.5140102623896163  worst: 0.24553665221312632
# ----------------------------------
# finish prediction
# model :  110
# best:  0.6849556025313335  worst: 0.2503539740557374
# ----------------------------------
# finish prediction
# model :  111
# best:  0.43826023252360263  worst: 0.2453664216319191
# ----------------------------------
# finish prediction
# model :  112
# best:  0.7294857285041316  worst: 0.24569285127159884
# ----------------------------------
# finish prediction
# model :  113
# best:  0.26049472640947935  worst: 0.11847492372237574
# ----------------------------------
# finish prediction
# model :  114
# best:  0.5206036430502519  worst: 0.3514490572823731
# ----------------------------------
# finish prediction
# model :  115
# best:  0.6684304246110595  worst: 0.25154509684851395
# ----------------------------------
# finish prediction
# model :  116
# best:  0.5045247868184989  worst: 0.2941597993614415
# ----------------------------------
# finish prediction
# model :  117
# best:  0.22885404748146107  worst: 0.03185196861864656
# ----------------------------------
# finish prediction
# model :  118
# best:  0.7646903683319966  worst: 0.2459848931403645
# ----------------------------------
# finish prediction
# model :  119
# best:  0.281779974776029  worst: 0.14454099108144597
# ----------------------------------
# finish prediction
# model :  120
# best:  0.24120930276035835  worst: 0.11341017209752399
# ----------------------------------
# finish prediction
# model :  121
# best:  0.775038706592984  worst: 0.2461090051918354
# ----------------------------------
# finish prediction
# model :  122
# best:  0.7726533015602295  worst: 0.24600694688253183
# ----------------------------------
# finish prediction
# model :  123
# best:  0.4196174096738295  worst: 0.24538720576391052
# ----------------------------------
# finish prediction
# model :  124
# best:  0.4092285664421746  worst: 0.008611266689813234
# ----------------------------------
# finish prediction
# model :  125
# best:  0.5190592878073823  worst: 0.24538766957627034
# ----------------------------------
# finish prediction
# model :  126
# best:  0.2599584704486526  worst: 0.0582089862148246
# ----------------------------------
# finish prediction
# model :  127
# best:  0.780678443986045  worst: 0.24682487660765073
# ----------------------------------
# finish prediction
# model :  128
# best:  0.5083480785114673  worst: 0.3097127108231624
# ----------------------------------
# finish prediction
# model :  129
# best:  0.13368426694347693  worst: 0.0036373086705601214
# ----------------------------------
# finish prediction
# model :  130
# best:  0.5282017857907068  worst: 0.37390631592816
# ----------------------------------
# finish prediction
# model :  131
# best:  0.7540136753052992  worst: 0.2516543936200069
# ----------------------------------
# finish prediction
# model :  132
# best:  0.7565325288318224  worst: 0.24605734167686388
# ----------------------------------
# finish prediction
# model :  133
# best:  0.5041854209829373  worst: 0.28433019932625175
# ----------------------------------
# finish prediction
# model :  134
# best:  0.5161294905593461  worst: 0.3110372162600711
# ----------------------------------
# finish prediction
# model :  135
# best:  0.47860017500161695  worst: 0.2699824955220577
# ----------------------------------
# finish prediction
# model :  136
# best:  0.7617975701551171  worst: 0.24593934605781032
# ----------------------------------
# finish prediction
# model :  137
# best:  0.4778466723365994  worst: 0.27398809011845193
# ----------------------------------
# finish prediction
# model :  138
# best:  0.4798218476008742  worst: 0.352546561069135
# ----------------------------------
# finish prediction
# model :  139
# best:  0.4837541313384036  worst: 0.2746779664968962
# ----------------------------------
# finish prediction
# model :  140
# best:  0.5675299735089769  worst: 0.2500720372384152
# ----------------------------------
# finish prediction
# model :  141
# best:  0.47359456616156936  worst: 0.2484504666014559
# ----------------------------------
# finish prediction
# model :  142
# best:  0.4980576573407602  worst: 0.36606682583867045
# ----------------------------------
# finish prediction
# model :  143
# best:  0.5080152253734272  worst: 0.2996532896549072
# ----------------------------------
# finish prediction
# model :  144
# best:  0.283001137190502  worst: 0.16020605263104862
# ----------------------------------
# finish prediction
# model :  145
# best:  0.4250688546366045  worst: 0.005545610735078613
# ----------------------------------
# finish prediction
# model :  146
# best:  0.5123748107029416  worst: 0.29191414738249233
# ----------------------------------
# finish prediction
# model :  147
# best:  0.47881786981752156  worst: 0.288472108532872
# ----------------------------------
# finish prediction
# model :  148
# best:  0.7590743825100235  worst: 0.24606046498774506
# ----------------------------------
# finish prediction
# model :  149
# best:  0.5096428772676176  worst: 0.3013147751261147
# ----------------------------------
# finish prediction
# model :  150
# best:  0.773034260381945  worst: 0.2459932338685042
# ----------------------------------
# finish prediction
# model :  151
# best:  0.5340202457547006  worst: 0.3914036818439216
# ----------------------------------
# finish prediction
# model :  152
# best:  0.26996613241380385  worst: 0.14293711543714194
# ----------------------------------
# finish prediction
# model :  153
# best:  0.23015010993599735  worst: 0.03330845472493417
# ----------------------------------
# finish prediction
# model :  154
# best:  0.43019091976525764  worst: 0.015855165453249012
# ----------------------------------
# finish prediction
# model :  155
# best:  0.6683906638573106  worst: 0.25166839646943884
# ----------------------------------
# finish prediction
# model :  156
# best:  0.5085550628223698  worst: 0.34433922110495985
# ----------------------------------
# finish prediction
# model :  157
# best:  0.2590084943782359  worst: 0.045484874574682845
# ----------------------------------
# finish prediction
# model :  158
# best:  0.5307068288636381  worst: 0.3853687225092979
# ----------------------------------
# finish prediction
# model :  159
# best:  0.5117516607047596  worst: 0.29792594590864846
# ----------------------------------
# finish prediction
# model :  160
# best:  0.7810040645433904  worst: 0.2477431634090304
# ----------------------------------
# finish prediction
# model :  161
# best:  0.3537277987982383  worst: 0.0033674225760709662
# ----------------------------------
# finish prediction
# model :  162
# best:  0.7603521721229836  worst: 0.24649051344431117
# ----------------------------------
# finish prediction
# model :  163
# best:  0.5486841544515507  worst: 0.25008923894258717
# ----------------------------------
# finish prediction
# model :  164
# best:  0.5240960600300699  worst: 0.31475594411438584
# ----------------------------------
# finish prediction
# model :  165
# best:  0.5112601553255616  worst: 0.31700806775663415
# ----------------------------------
# finish prediction
# model :  166
# best:  0.2678482691246193  worst: 0.03892836260548943
# ----------------------------------
# finish prediction
# model :  167
# best:  0.7652682221868421  worst: 0.2459958507939212
# ----------------------------------
# finish prediction
# model :  168
# best:  0.5032724101449406  worst: 0.28467053633345896
# ----------------------------------
# finish prediction
# model :  169
# best:  0.48097877936280287  worst: 0.3292562781504511
# ----------------------------------
# finish prediction
# model :  170
# best:  0.5327444129484484  worst: 0.24873031002361315
# ----------------------------------
# finish prediction
# model :  171
# best:  0.513017266453033  worst: 0.3830217334006021
# ----------------------------------
# finish prediction
# model :  172
# best:  0.25578278210542704  worst: 0.007457176096846332
# ----------------------------------
# finish prediction
# model :  173
# best:  0.5036264445868108  worst: 0.3293804287724803
# ----------------------------------
# finish prediction
# model :  174
# best:  0.5142456478827357  worst: 0.2897623360825016
# ----------------------------------
# finish prediction
# model :  175
# best:  0.41589627525035405  worst: 0.0054337102532616725
# ----------------------------------
# finish prediction
# model :  176
# best:  0.685113489113242  worst: 0.25120883304095143
# ----------------------------------
# finish prediction
# model :  177
# best:  0.5209378955398885  worst: 0.4022993047378882
# ----------------------------------
# finish prediction
# model :  178
# best:  0.256192247688117  worst: 0.1381297118865601
# ----------------------------------
# finish prediction
# model :  179
# best:  0.7529564213834148  worst: 0.24824233498279183
# ----------------------------------
# finish prediction
# model :  180
# best:  0.2726690539590257  worst: 0.026988701600746207
# ----------------------------------
# finish prediction
# model :  181
# best:  0.7767375692295331  worst: 0.25457311909699
# ----------------------------------
# finish prediction
# model :  182
# best:  0.5083259863250142  worst: 0.30505700101171307
# ----------------------------------
# finish prediction
# model :  183
# best:  0.5166551860996983  worst: 0.3921276505503778
# ----------------------------------
# finish prediction
# model :  184
# best:  0.4073295119642256  worst: 0.004998101880009253
# ----------------------------------
# finish prediction
# model :  185
# best:  0.5235602442981278  worst: 0.3212787319222056
# ----------------------------------
# finish prediction
# model :  186
# best:  0.7869190349810679  worst: 0.24728733974583034
# ----------------------------------
# finish prediction
# model :  187
# best:  0.5545498180785897  worst: 0.24545480960764848
# ----------------------------------
# finish prediction
# model :  188
# best:  0.11880347123050303  worst: 0.0036510242322072835
# ----------------------------------
# finish prediction
# model :  189
# best:  0.5145888356371136  worst: 0.29597766058272684
# ----------------------------------
# finish prediction
# model :  190
# best:  0.5285986362232702  worst: 0.31083403098234047
# ----------------------------------
# finish prediction
# model :  191
# best:  0.792109819724957  worst: 0.24657081429717956
# ----------------------------------
# finish prediction
# model :  192
# best:  0.7915207301434684  worst: 0.25366745681701347
# ----------------------------------
# finish prediction
# model :  193
# best:  0.6384451238900197  worst: 0.251105353658097
# ----------------------------------
# finish prediction
# model :  194
# best:  0.5038916753519385  worst: 0.3009771437985744
# ----------------------------------
# finish prediction
# model :  195
# best:  0.511785055304527  worst: 0.29794813231099837
# ----------------------------------
# finish prediction
# model :  196
# best:  0.5294823575896452  worst: 0.29581812393345086
# ----------------------------------
# finish prediction
# model :  197
# best:  0.36993066292196597  worst: 0.007293543635462124
# ----------------------------------
# finish prediction
# model :  198
# best:  0.766059034960128  worst: 0.24632594976604538
# ----------------------------------
# finish prediction
# model :  199
# best:  0.47889756708251663  worst: 0.271477457010991
# ----------------------------------
# finish prediction
# model :  200
# best:  0.6324459315321499  worst: 0.250839761203244
# ----------------------------------
# finish prediction
# model :  201
# best:  0.7642650087000135  worst: 0.24597153839981814
# ----------------------------------
# finish prediction
# model :  202
# best:  0.48836134419080307  worst: 0.2484818500128669
# ----------------------------------
# finish prediction
# model :  203
# best:  0.233688018796298  worst: 0.003696944488163348
# ----------------------------------
# finish prediction
# model :  204
# best:  0.2338396515809348  worst: 0.012241178525850584
# ----------------------------------
# finish prediction
# model :  205
# best:  0.5158226014999732  worst: 0.2485592693065538
# ----------------------------------
# finish prediction
# model :  206
# best:  0.5086993168825064  worst: 0.3069644478968937
# ----------------------------------
# finish prediction
# model :  207
# best:  0.26201275550667735  worst: 0.08232061443250246
# ----------------------------------
# finish prediction
# model :  208
# best:  0.7783958652630956  worst: 0.2464933434697524
# ----------------------------------
# finish prediction
# model :  209
# best:  0.7782587082104784  worst: 0.24597137225043952
# ----------------------------------
# finish prediction
# model :  210
# best:  0.5034473937895642  worst: 0.28649517502633465
# ----------------------------------
# finish prediction
# model :  211
# best:  0.7921636330660621  worst: 0.24714063865448282
# ----------------------------------
# finish prediction
# model :  212
# best:  0.5320112637283461  worst: 0.3940245360487725
# ----------------------------------
# finish prediction
# model :  213
# best:  0.7499098631514276  worst: 0.24657005828334896
# ----------------------------------
# finish prediction
# model :  214
# best:  0.5089305184845501  worst: 0.31166865988595843
# ----------------------------------
# finish prediction
# model :  215
# best:  0.25584719149099133  worst: 0.0469414312525563
# ----------------------------------
# finish prediction
# model :  216
# best:  0.5050328122804573  worst: 0.30228625130733655
# ----------------------------------
# finish prediction
# model :  217
# best:  0.8299193983842351  worst: 0.387530914153563
# ----------------------------------
# finish prediction
# model :  218
# best:  0.5142977348206816  worst: 0.305828783638703
# ----------------------------------
# finish prediction
# model :  219
# best:  0.4776930524276538  worst: 0.2743377639958028
# ----------------------------------
# finish prediction
# model :  220
# best:  0.5148385967119323  worst: 0.38131644688443783
# ----------------------------------
# finish prediction
# model :  221
# best:  0.8022266288300964  worst: 0.2961185742809844
# ----------------------------------
# finish prediction
# model :  222
# best:  0.5111825769926582  worst: 0.29922703904382014
# ----------------------------------
# finish prediction
# model :  223
# best:  0.33144935160126704  worst: 0.0018330961845198905
# ----------------------------------
# finish prediction
# model :  224
# best:  0.47486588475752234  worst: 0.2694635724524353
# ----------------------------------
# finish prediction
# model :  225
# best:  0.612799335478152  worst: 0.2507112705531198
# ----------------------------------
# finish prediction
# model :  226
# best:  0.5072365203833485  worst: 0.29301337397874966
# ----------------------------------
# finish prediction
# model :  227
# best:  0.49529357557193926  worst: 0.3508495787559246
# ----------------------------------
# finish prediction
# model :  228
# best:  0.47779909938933607  worst: 0.2700450100913688
# ----------------------------------
# finish prediction
# model :  229
# best:  0.2510201136331031  worst: 0.02999778150161871
# ----------------------------------
# finish prediction
# model :  230
# best:  0.503290194549874  worst: 0.24868221562488493
# ----------------------------------
# finish prediction
# model :  231
# best:  0.5152552585549636  worst: 0.24777275825777217
# ----------------------------------
# finish prediction
# model :  232
# best:  0.5096588342382844  worst: 0.2479180224955027
# ----------------------------------
# finish prediction
# model :  233
# best:  0.7724807551517797  worst: 0.24662317432381092
# ----------------------------------
# finish prediction
# model :  234
# best:  0.47899186346026307  worst: 0.27524529078037185
# ----------------------------------
# finish prediction
# model :  235
# best:  0.7578240943889003  worst: 0.24623273305822363
# ----------------------------------
# finish prediction
# model :  236
# best:  0.5056073518254987  worst: 0.30418258855155617
# ----------------------------------
# finish prediction
# model :  237
# best:  0.5580976407241472  worst: 0.2501012969427031
# ----------------------------------
# finish prediction
# model :  238
# best:  0.51799631675548  worst: 0.3653516309634466
# ----------------------------------
# finish prediction
# model :  239
# best:  0.5105275848049224  worst: 0.3800449879417173
# ----------------------------------
# finish prediction
# model :  240
# best:  0.662516492760165  worst: 0.2516047110004287
# ----------------------------------
# finish prediction
# model :  241
# best:  0.5215798510866512  worst: 0.32509026323234336
# ----------------------------------
# finish prediction
# model :  242
# best:  0.25516999764034426  worst: 0.059486097176218874
# ----------------------------------
# finish prediction
# model :  243
# best:  0.518182598185729  worst: 0.3656429613163589
# ----------------------------------
# finish prediction
# model :  244
# best:  0.1540977712788934  worst: 0.0020377316292774688
# ----------------------------------
# finish prediction
# model :  245
# best:  0.519173437412433  worst: 0.341315184275386
# ----------------------------------
# finish prediction
# model :  246
# best:  0.5229397929315078  worst: 0.32127636096558665
# ----------------------------------
# finish prediction
# model :  247
# best:  0.4791862203115382  worst: 0.27001038566219054
# ----------------------------------
# finish prediction
# model :  248
# best:  0.5103904916410591  worst: 0.3807959496694698
# ----------------------------------
# finish prediction
# model :  249
# best:  0.7823794956715096  worst: 0.24730664763091625
# ----------------------------------
# finish prediction
# model :  250
# best:  0.4988272562712721  worst: 0.3737672803495007
# ----------------------------------
# finish prediction
# model :  251
# best:  0.5080907954168691  worst: 0.30866984040130746
# ----------------------------------
# finish prediction
# model :  252
# best:  0.5059768833587892  worst: 0.3009160816563642
# ----------------------------------
# finish prediction
# model :  253
# best:  0.26522745567431355  worst: 0.038759187265000834
# ----------------------------------
# finish prediction
# model :  254
# best:  0.535873560363664  worst: 0.248303874858079
# ----------------------------------
# finish prediction
# model :  255
# best:  0.428550801815447  worst: 0.005513839890230621
# ----------------------------------
# finish prediction
# model :  256
# best:  0.25956602445289356  worst: 0.05127519229448528
# ----------------------------------
# finish prediction
# model :  257
# best:  0.5306454157759388  worst: 0.2491625958242867
# ----------------------------------
# finish prediction
# model :  258
# best:  0.5069079362036876  worst: 0.3235329073118667
# ----------------------------------
# finish prediction
# model :  259
# best:  0.783063842464844  worst: 0.24982573543702047
# ----------------------------------
# finish prediction
# model :  260
# best:  0.5224056388296686  worst: 0.3102685986937742
# ----------------------------------
# finish prediction
# model :  261
# best:  0.6674744074219272  worst: 0.24556370438592026
# ----------------------------------
# finish prediction
# model :  262
# best:  0.510463470724319  worst: 0.31070118093904275
# ----------------------------------
# finish prediction
# model :  263
# best:  0.7881039239197496  worst: 0.2468093540691357
# ----------------------------------
# finish prediction
# model :  264
# best:  0.7942960669047127  worst: 0.3437234949287108
# ----------------------------------
# finish prediction
# model :  265
# best:  0.5320847400984827  worst: 0.30849064346148397
# ----------------------------------
# finish prediction
# model :  266
# best:  0.5258719463325249  worst: 0.29739998064186235
# ----------------------------------
# finish prediction
# model :  267
# best:  0.4819892547817571  worst: 0.3135736377375605
# ----------------------------------
# finish prediction
# model :  268
# best:  0.23963161673644365  worst: 0.0462468648147917
# ----------------------------------
# finish prediction
# model :  269
# best:  0.2849612095518076  worst: 0.15757440034710235
# ----------------------------------
# finish prediction
# model :  270
# best:  0.6648643785028416  worst: 0.25161171984206243
# ----------------------------------
# finish prediction
# model :  271
# best:  0.5177032421139046  worst: 0.38802333204332656
# ----------------------------------
# finish prediction
# model :  272
# best:  0.4845761819462297  worst: 0.27758934788091005
# ----------------------------------
# finish prediction
# model :  273
# best:  0.5598057327271722  worst: 0.2500004351429135
# ----------------------------------
# finish prediction
# model :  274
# best:  0.5080302694449812  worst: 0.2966277296868373
# ----------------------------------
# finish prediction
# model :  275
# best:  0.5067133658127525  worst: 0.2953048373142524
# ----------------------------------
# finish prediction
# model :  276
# best:  0.7886342011243784  worst: 0.24697039903108323
# ----------------------------------
# finish prediction
# model :  277
# best:  0.5945850362966658  worst: 0.24541911670968922
# ----------------------------------
# finish prediction
# model :  278
# best:  0.6232872492114213  worst: 0.4354353569310102
# ----------------------------------
# finish prediction
# model :  279
# best:  0.5081983704988214  worst: 0.30609575813981915
# ----------------------------------
# finish prediction
# model :  280
# best:  0.8042106155484245  worst: 0.26291204267959245
# ----------------------------------
# finish prediction
# model :  281
# best:  0.3606245004159267  worst: 0.2459968824487536
# ----------------------------------
# finish prediction
# model :  282
# best:  0.31001351402247435  worst: 0.15243417494590936
# ----------------------------------
# finish prediction
# model :  283
# best:  0.8149485950145965  worst: 0.2570705442363304
# ----------------------------------
# finish prediction
# model :  284
# best:  0.6874496823914975  worst: 0.2504859685623199
# ----------------------------------
# finish prediction
# model :  285
# best:  0.23103958906518854  worst: 0.0321113642677178
# ----------------------------------
# finish prediction
# model :  286
# best:  0.5577648575690619  worst: 0.33322853749674963
# ----------------------------------
# finish prediction
# model :  287
# best:  0.8075179303410458  worst: 0.25244534166780297
# ----------------------------------
# finish prediction
# model :  288
# best:  0.5118146826719587  worst: 0.3770765180369309
# ----------------------------------
# finish prediction
# model :  289
# best:  0.5379169969385861  worst: 0.34573444806211895
# ----------------------------------
# finish prediction
# model :  290
# best:  0.4499083441399858  worst: 0.24536947858673594
# ----------------------------------
# finish prediction
# model :  291
# best:  0.5195270057961673  worst: 0.38627315102135246
# ----------------------------------
# finish prediction
# model :  292
# best:  0.47772829181988674  worst: 0.3506790575908986
# ----------------------------------
# finish prediction
# model :  293
# best:  0.4906141538369155  worst: 0.2963664382388699
# ----------------------------------
# finish prediction
# model :  294
# best:  0.5345600151588112  worst: 0.24876715830839932
# ----------------------------------
# finish prediction
# model :  295
# best:  0.53989249001149  worst: 0.24877106031540913
# ----------------------------------
# finish prediction
# model :  296
# best:  0.4416199929088603  worst: 0.24825164402195413
# ----------------------------------
# finish prediction
# model :  297
# best:  0.7867855030196242  worst: 0.24642481383594542
# ----------------------------------
# finish prediction
# model :  298
# best:  0.5120164979374061  worst: 0.24853294202368714
# ----------------------------------
# finish prediction
# model :  299
# best:  0.4129541073573517  worst: 0.005525655305964899
# ----------------------------------
# finish prediction
# model :  300
# best:  0.5165837600240182  worst: 0.3601157995424868
# ----------------------------------
# finish prediction
# model :  301
# best:  0.24155761716965887  worst: 0.031103217390082774
# ----------------------------------
# finish prediction
# model :  302
# best:  0.6730359333815115  worst: 0.25161431075914137
# ----------------------------------
# finish prediction
# model :  303
# best:  0.47291752843774243  worst: 0.010679691065772722
# ----------------------------------
# finish prediction
# model :  304
# best:  0.5192326416534043  worst: 0.31253985584327976
# ----------------------------------
# finish prediction
# model :  305
# best:  0.6242487275189641  worst: 0.2503939117811496
# ----------------------------------
# finish prediction
# model :  306
# best:  0.5127224798856461  worst: 0.2992299945276068
# ----------------------------------
# finish prediction
# model :  307
# best:  0.48336493457955726  worst: 0.2478150588092843
# ----------------------------------
# finish prediction
# model :  308
# best:  0.49052274850189903  worst: 0.24795214052083167
# ----------------------------------
# finish prediction
# model :  309
# best:  0.7713394232111714  worst: 0.24780412753845318
# ----------------------------------
# finish prediction
# model :  310
# best:  0.5206164200624325  worst: 0.341640693287689
# ----------------------------------
# finish prediction
# model :  311
# best:  0.4788823189687694  worst: 0.28691378481764007
# ----------------------------------
# finish prediction
# model :  312
# best:  0.5300469156767963  worst: 0.26437618172539434
# ----------------------------------
# finish prediction
# model :  313
# best:  0.510412631404798  worst: 0.2972687475112459
# ----------------------------------
# finish prediction
# model :  314
# best:  0.3598956850084907  worst: 0.24596556766183122
# ----------------------------------
# finish prediction
# model :  315
# best:  0.772847685775335  worst: 0.24639132400026295
# ----------------------------------
# finish prediction
# model :  316
# best:  0.5425929352176  worst: 0.2488826407540504
# ----------------------------------
# finish prediction
# model :  317
# best:  0.49938328465458953  worst: 0.24850373621045213
# ----------------------------------
# finish prediction
# model :  318
# best:  0.43132190538115084  worst: 0.005512872368993204
# ----------------------------------
# finish prediction
# model :  319
# best:  0.7736468621149462  worst: 0.24602146845414916
# ----------------------------------
# finish prediction
# model :  320
# best:  0.552632625529991  worst: 0.2498902399050536
# ----------------------------------
# finish prediction
# model :  321
# best:  0.5146018003891155  worst: 0.32464274125991055
# ----------------------------------
# finish prediction
# model :  322
# best:  0.6811873704496164  worst: 0.2522833994963094
# ----------------------------------
# finish prediction
# model :  323
# best:  0.6344879419964992  worst: 0.25073134711515166
# ----------------------------------
# finish prediction
# model :  324
# best:  0.26169405492369724  worst: 0.05598428949972435
# ----------------------------------
# finish prediction
# model :  325
# best:  0.4796598705046594  worst: 0.28416837739770545
# ----------------------------------
# finish prediction
# model :  326
# best:  0.7968343189479822  worst: 0.24963695125120366
# ----------------------------------
# finish prediction
# model :  327
# best:  0.7840992737698432  worst: 0.24642044177595174
# ----------------------------------
# finish prediction
# model :  328
# best:  0.5780565339456174  worst: 0.25024343955943057
# ----------------------------------
# finish prediction
# model :  329
# best:  0.5162784266201664  worst: 0.377329321708179
# ----------------------------------
# finish prediction
# model :  330
# best:  0.29698829719230985  worst: 0.0062773814031676384
# ----------------------------------
# finish prediction
# model :  331
# best:  0.8008189559382826  worst: 0.24740247324604062
# ----------------------------------
# finish prediction
# model :  332
# best:  0.23482524958465095  worst: 0.038931148100778884
# ----------------------------------
# finish prediction
# model :  333
# best:  0.4322157203768977  worst: 0.24805542780258746
# ----------------------------------
# finish prediction
# model :  334
# best:  0.514431137852864  worst: 0.36670182960462344
# ----------------------------------
# finish prediction
# model :  335
# best:  0.5072792350773475  worst: 0.36804126738287546
# ----------------------------------
# finish prediction
# model :  336
# best:  0.4856107125425208  worst: 0.37205858882223736
# ----------------------------------
# finish prediction
# model :  337
# best:  0.529554205616743  worst: 0.2490142986252966
# ----------------------------------
# finish prediction
# model :  338
# best:  0.4662417356936168  worst: 0.24850375779440118
# ----------------------------------
# finish prediction
# model :  339
# best:  0.2622460909158183  worst: 0.05742220326960093
# ----------------------------------
# finish prediction
# model :  340
# best:  0.5034114161462022  worst: 0.3690698869414864
# ----------------------------------
# finish prediction
# model :  341
# best:  0.6079920093303319  worst: 0.25029699191829474
# ----------------------------------
# finish prediction
# model :  342
# best:  0.4977368317460888  worst: 0.3283774838152766
# ----------------------------------
# finish prediction
# model :  343
# best:  0.7959490490289843  worst: 0.2486119618135882
# ----------------------------------
# finish prediction
# model :  344
# best:  0.5157018889849518  worst: 0.3682728251791686
# ----------------------------------
# finish prediction
# model :  345
# best:  0.4918898946860789  worst: 0.3433190889423386
# ----------------------------------
# finish prediction
# model :  346
# best:  0.6938955995643481  worst: 0.24546357911628988
# ----------------------------------
# finish prediction
# model :  347
# best:  0.7934605573650415  worst: 0.24697885168714256
# ----------------------------------
# finish prediction
# model :  348
# best:  0.24548448509588558  worst: 0.03616025816679501
# ----------------------------------
# finish prediction
# model :  349
# best:  0.7687648319130026  worst: 0.24618789842071098
# ----------------------------------
# finish prediction
# model :  350
# best:  0.47765704053199387  worst: 0.24848253117535546
# ----------------------------------
# finish prediction
# model :  351
# best:  0.5007472785768873  worst: 0.3640664501285436
# ----------------------------------
# finish prediction
# model :  352
# best:  0.5180627431541962  worst: 0.32858324592525584
# ----------------------------------
# finish prediction
# model :  353
# best:  0.5267329255012384  worst: 0.3123190426956084
# ----------------------------------
# finish prediction
# model :  354
# best:  0.5152626976026349  worst: 0.3725824213611845
# ----------------------------------
# finish prediction
# model :  355
# best:  0.4769465433053726  worst: 0.27754870695319406
# ----------------------------------
# finish prediction
# model :  356
# best:  0.5179875349013714  worst: 0.3504612365838295
# ----------------------------------
# finish prediction
# model :  357
# best:  0.5240116969795019  worst: 0.3037054185314466
# ----------------------------------
# finish prediction
# model :  358
# best:  0.515027286352807  worst: 0.33809568832734105
# ----------------------------------
# finish prediction
# model :  359
# best:  0.5212562319273847  worst: 0.3186801763897932
# ----------------------------------
# finish prediction
# model :  360
# best:  0.4519552655722056  worst: 0.24853106281685577
# ----------------------------------
# finish prediction
# model :  361
# best:  0.46799001728061373  worst: 0.24861127416327242
# ----------------------------------
# finish prediction
# model :  362
# best:  0.5189720423803057  worst: 0.3652656456324701
# ----------------------------------
# finish prediction
# model :  363
# best:  0.4801694327627879  worst: 0.31436058915052506
# ----------------------------------
# finish prediction
# model :  364
# best:  0.48054414804550527  worst: 0.2970534810863316
# ----------------------------------
# finish prediction
# model :  365
# best:  0.6866472027883626  worst: 0.25038137461993215
# ----------------------------------
# finish prediction
# model :  366
# best:  0.479300265198676  worst: 0.2995426161330611
# ----------------------------------
# finish prediction
# model :  367
# best:  0.4750489455119761  worst: 0.30333263162511787
# ----------------------------------
# finish prediction
# model :  368
# best:  0.48549596595340916  worst: 0.24866773330764183
# ----------------------------------
# finish prediction
# model :  369
# best:  0.5185498875215386  worst: 0.3170413048790046
# ----------------------------------
# finish prediction
# model :  370
# best:  0.2343157476376843  worst: 0.03497965304133614
# ----------------------------------
# finish prediction
# model :  371
# best:  0.21002081609063838  worst: 0.007149753357988118
# ----------------------------------
# finish prediction
# model :  372
# best:  0.47439320142940167  worst: 0.24862975670053405
# ----------------------------------
# finish prediction
# model :  373
# best:  0.5207809884058038  worst: 0.3804323776787166
# ----------------------------------
# finish prediction
# model :  374
# best:  0.7681017466325164  worst: 0.2460408682943865
# ----------------------------------
# finish prediction
# model :  375
# best:  0.5186468556639777  worst: 0.3722158692057228
# ----------------------------------
# finish prediction
# model :  376
# best:  0.45597981328279785  worst: 0.24790711230640222
# ----------------------------------
# finish prediction
# model :  377
# best:  0.25925404256078577  worst: 0.03030472184166321
# ----------------------------------
# finish prediction
# model :  378
# best:  0.517177827368597  worst: 0.33037788458645484
# ----------------------------------
# finish prediction
# model :  379
# best:  0.5044854750543449  worst: 0.29758558365381393
# ----------------------------------
# finish prediction
# model :  380
# best:  0.517904713267739  worst: 0.3849889263431188
# ----------------------------------
# finish prediction
# model :  381
# best:  0.5225922046776006  worst: 0.38223413820677965
# ----------------------------------
# finish prediction
# model :  382
# best:  0.5148953544856993  worst: 0.3657591646385723
# ----------------------------------
# finish prediction
# model :  383
# best:  0.5202105003439699  worst: 0.2972346545705308
# ----------------------------------
# finish prediction
# model :  384
# best:  0.5058500928226394  worst: 0.2962487409950654
# ----------------------------------
# finish prediction
# model :  385
# best:  0.4973759414305583  worst: 0.2485493367795868
# ----------------------------------
# finish prediction
# model :  386
# best:  0.7837706038635743  worst: 0.247995988681212
# ----------------------------------
# finish prediction
# model :  387
# best:  0.4889093878999751  worst: 0.2480265234801388
# ----------------------------------
# finish prediction
# model :  388
# best:  0.4667654988660211  worst: 0.015948829851865284
# ----------------------------------
# finish prediction
# model :  389
# best:  0.5334757607735279  worst: 0.24807628234757417
# ----------------------------------
# finish prediction
# model :  390
# best:  0.49634326963147857  worst: 0.3426642279230322
# ----------------------------------
# finish prediction
# model :  391
# best:  0.802218130929137  worst: 0.2586058542941994
# ----------------------------------
# finish prediction
# model :  392
# best:  0.5235945786318765  worst: 0.3145310268520997
# ----------------------------------
# finish prediction
# model :  393
# best:  0.4769221497935604  worst: 0.24865467554750353
# ----------------------------------
# finish prediction
# model :  394
# best:  0.4613159520808708  worst: 0.24833249928606538
# ----------------------------------
# finish prediction
# model :  395
# best:  0.47303432693491293  worst: 0.2996398937054681
# ----------------------------------
# finish prediction
# model :  396
# best:  0.5432955505410416  worst: 0.248873190182035
# ----------------------------------
# finish prediction
# model :  397
# best:  0.4769844231774268  worst: 0.3190277326522256
# ----------------------------------
# finish prediction
# model :  398
# best:  0.4605770339128111  worst: 0.24806546841561347
# ----------------------------------
# finish prediction
# model :  399
# best:  0.5037983867624727  worst: 0.3664999836276813
# ----------------------------------
# finish prediction
# model :  400
# best:  0.5196201277982309  worst: 0.3284010877155721
# ----------------------------------
# finish prediction
# model :  401
# best:  0.4765191988778321  worst: 0.3477880743750072
# ----------------------------------
# finish prediction
# model :  402
# best:  0.5171383687974731  worst: 0.3781647090920795
# ----------------------------------
# finish prediction
# model :  403
# best:  0.5227001609012081  worst: 0.37937793596486374
# ----------------------------------
# finish prediction
# model :  404
# best:  0.4371431726366507  worst: 0.005538730740171805
# ----------------------------------
# finish prediction
# model :  405
# best:  0.5235013793525894  worst: 0.37551051501039195
# ----------------------------------
# finish prediction
# model :  406
# best:  0.5163864376365337  worst: 0.3394943098402895
# ----------------------------------
# finish prediction
# model :  407
# best:  0.7717226291741476  worst: 0.2462344147779071
# ----------------------------------
# finish prediction
# model :  408
# best:  0.5013029764860732  worst: 0.3824967857702302
# ----------------------------------
# finish prediction
# model :  409
# best:  0.517221539738588  worst: 0.38634610860708973
# ----------------------------------
# finish prediction
# model :  410
# best:  0.256321709202187  worst: 0.030334223657908034
# ----------------------------------
# finish prediction
# model :  411
# best:  0.17926547060315925  worst: 0.006607175063927525
# ----------------------------------
# finish prediction
# model :  412
# best:  0.5034113454734087  worst: 0.37812682711970447
# ----------------------------------
# finish prediction
# model :  413
# best:  0.457038431445649  worst: 0.24882203631782912
# ----------------------------------
# finish prediction
# model :  414
# best:  0.5182779968321518  worst: 0.38446143425598045
# ----------------------------------
# finish prediction
# model :  415
# best:  0.7672218494608841  worst: 0.24597396660115287
# ----------------------------------
# finish prediction
# model :  416
# best:  0.8056759365790562  worst: 0.2978943788108667
# ----------------------------------
# finish prediction
# model :  417
# best:  0.5192286683831915  worst: 0.38134952085384627
# ----------------------------------
# finish prediction
# model :  418
# best:  0.7192859014145161  worst: 0.2453871432474756
# ----------------------------------
# finish prediction
# model :  419
# best:  0.5150234920807855  worst: 0.3505794611485618
# ----------------------------------
# finish prediction
# model :  420
# best:  0.5173607527811175  worst: 0.369462104699704
# ----------------------------------
# finish prediction
# model :  421
# best:  0.5170034180580391  worst: 0.31416953548872395
# ----------------------------------
# finish prediction
# model :  422
# best:  0.26231215904936456  worst: 0.028635433063809983
# ----------------------------------
# finish prediction
# model :  423
# best:  0.5202862791600821  worst: 0.38668897867419644
# ----------------------------------
# finish prediction
# model :  424
# best:  0.5175241380627469  worst: 0.3846408693722112
# ----------------------------------
# finish prediction
# model :  425
# best:  0.7968196175551088  worst: 0.4630269082427044
# ----------------------------------
# finish prediction
# model :  426
# best:  0.502817901418547  worst: 0.24789900539484297
# ----------------------------------
# finish prediction
# model :  427
# best:  0.5201692651265911  worst: 0.38459137262375764
# ----------------------------------
# finish prediction
# model :  428
# best:  0.4803210230424099  worst: 0.2899262660408521
# ----------------------------------
# finish prediction
# model :  429
# best:  0.46715326787786204  worst: 0.2485755938006981
# ----------------------------------
# finish prediction
# model :  430
# best:  0.23629244515667833  worst: 0.08534732600458396
# ----------------------------------
# finish prediction
# model :  431
# best:  0.4360670869919345  worst: 0.24831556643669936
# ----------------------------------
# finish prediction
# model :  432
# best:  0.5207300645111815  worst: 0.3682650317086385
# ----------------------------------
# finish prediction
# model :  433
# best:  0.5199219707853853  worst: 0.3746281996076493
# ----------------------------------
# finish prediction
# model :  434
# best:  0.6712490752375238  worst: 0.250625835877459
# ----------------------------------
# finish prediction
# model :  435
# best:  0.5234496174179493  worst: 0.3433346558641208
# ----------------------------------
# finish prediction
# model :  436
# best:  0.5512163758408583  worst: 0.2485114355897806
# ----------------------------------
# finish prediction
# model :  437
# best:  0.7633533546035093  worst: 0.246631145483033
# ----------------------------------
# finish prediction
# model :  438
# best:  0.4897569181814462  worst: 0.24796268215492265
# ----------------------------------
# finish prediction
# model :  439
# best:  0.5228992475014739  worst: 0.31809615459030305
# ----------------------------------
# finish prediction
# model :  440
# best:  0.2447366359007469  worst: 0.06563422232419645
# ----------------------------------
# finish prediction
# model :  441
# best:  0.4793904255062532  worst: 0.2874875715371037
# ----------------------------------
# finish prediction
# model :  442
# best:  0.50783727740709  worst: 0.36915486133655395
# ----------------------------------
# finish prediction
# model :  443
# best:  0.22521702457384044  worst: 0.03343853455241792
# ----------------------------------
# finish prediction
# model :  444
# best:  0.5253114260807247  worst: 0.24833089293782779
# ----------------------------------
# finish prediction
# model :  445
# best:  0.5089414626342297  worst: 0.31232083779688524
# ----------------------------------
# finish prediction
# model :  446
# best:  0.4875058976514043  worst: 0.29798469136784445
# ----------------------------------
# finish prediction
# model :  447
# best:  0.8078813045640314  worst: 0.254794756760197
# ----------------------------------
# finish prediction
# model :  448
# best:  0.700595558108405  worst: 0.4761740719056658
# ----------------------------------
# finish prediction
# model :  449
# best:  0.515665913179808  worst: 0.37331755746377465
# ----------------------------------
# finish prediction
# model :  450
# best:  0.5265258974422621  worst: 0.3760415890887396
# ----------------------------------
# finish prediction
# model :  451
# best:  0.4782525821148797  worst: 0.3104073980126618
# ----------------------------------
# finish prediction
# model :  452
# best:  0.4779431925668488  worst: 0.34777838239923886
# ----------------------------------
# finish prediction
# model :  453
# best:  0.796672199628239  worst: 0.46125156455154975
# ----------------------------------
# finish prediction
# model :  454
# best:  0.5207776365383577  worst: 0.3261602401343419
# ----------------------------------
# finish prediction
# model :  455
# best:  0.5179224785322455  worst: 0.3654045271316216
# ----------------------------------
# finish prediction
# model :  456
# best:  0.702084540897619  worst: 0.24673769269109092
# ----------------------------------
# finish prediction
# model :  457
# best:  0.47890596816620445  worst: 0.2689832113897077
# ----------------------------------
# finish prediction
# model :  458
# best:  0.5103585968091277  worst: 0.371052128871194
# ----------------------------------
# finish prediction
# model :  459
# best:  0.5217985527472075  worst: 0.38164114117752096
# ----------------------------------
# finish prediction
# model :  460
# best:  0.5130600791590335  worst: 0.37802874862909663
# ----------------------------------
# finish prediction
# model :  461
# best:  0.7744518573591153  worst: 0.24656626473741572
# ----------------------------------
# finish prediction
# model :  462
# best:  0.35231069079264954  worst: 0.006954881325435666
# ----------------------------------
# finish prediction
# model :  463
# best:  0.5152703361826544  worst: 0.3596528216880168
# ----------------------------------
# finish prediction
# model :  464
# best:  0.5212112947888392  worst: 0.38221843426649377
# ----------------------------------
# finish prediction
# model :  465
# best:  0.5183525764579431  worst: 0.31866841052063777
# ----------------------------------
# finish prediction
# model :  466
# best:  0.5148266927779641  worst: 0.453196128430037
# ----------------------------------
# finish prediction
# model :  467
# best:  0.20038124462256246  worst: 0.006042856344449311
# ----------------------------------
# finish prediction
# model :  468
# best:  0.5273788067687518  worst: 0.24834301489961635
# ----------------------------------
# finish prediction
# model :  469
# best:  0.21797414345574379  worst: 0.050497420813880985
# ----------------------------------
# finish prediction
# model :  470
# best:  0.2720911361902985  worst: 0.09643030038130719
# ----------------------------------
# finish prediction
# model :  471
# best:  0.4757057251131245  worst: 0.29526097455734424
# ----------------------------------
# finish prediction
# model :  472
# best:  0.5136175912539437  worst: 0.36733879733700625
# ----------------------------------
# finish prediction
# model :  473
# best:  0.7958696886569454  worst: 0.2470530664124132
# ----------------------------------
# finish prediction
# model :  474
# best:  0.5224028293892489  worst: 0.34139316507779155
# ----------------------------------
# finish prediction
# model :  475
# best:  0.4130709330107576  worst: 0.005539002275847895
# ----------------------------------
# finish prediction
# model :  476
# best:  0.5113237100211991  worst: 0.28233656545568125
# ----------------------------------
# finish prediction
# model :  477
# best:  0.5162735386064943  worst: 0.3388502522865438
# ----------------------------------
# finish prediction
# model :  478
# best:  0.09524194097730496  worst: 0.005871426633758096
# ----------------------------------
# finish prediction
# model :  479
# best:  0.7596445852443829  worst: 0.2463111974780569
# ----------------------------------
# finish prediction
# model :  480
# best:  0.5184624607380235  worst: 0.3140207710144429
# ----------------------------------
# finish prediction
# model :  481
# best:  0.5161582963059794  worst: 0.3674499884683595
# ----------------------------------
# finish prediction
# model :  482
# best:  0.5146519747131777  worst: 0.3377509108636041
# ----------------------------------
# finish prediction
# model :  483
# best:  0.5092424656586612  worst: 0.2855440787572544
# ----------------------------------
# finish prediction
# model :  484
# best:  0.6582470509363945  worst: 0.25076131269536317
# ----------------------------------
# finish prediction
# model :  485
# best:  0.5041543891606459  worst: 0.2670325944858139
# ----------------------------------
# finish prediction
# model :  486
# best:  0.5780413973861143  worst: 0.30423870309840756
# ----------------------------------
# finish prediction
# model :  487
# best:  0.2806336476211209  worst: 0.006269268201744437
# ----------------------------------
# finish prediction
# model :  488
# best:  0.774810579737314  worst: 0.24616467206562162
# ----------------------------------
# finish prediction
# model :  489
# best:  0.5220985016342513  worst: 0.32403754293052167
# ----------------------------------
# finish prediction
# model :  490
# best:  0.1152074437417682  worst: 0.0068349722315100185
# ----------------------------------
# finish prediction
# model :  491
# best:  0.28484022373133944  worst: 0.006368817742686391
# ----------------------------------
# finish prediction
# model :  492
# best:  0.5178806950536687  worst: 0.24858184156739868
# ----------------------------------
# finish prediction
# model :  493
# best:  0.5186725583973408  worst: 0.31913755233068863
# ----------------------------------
# finish prediction
# model :  494
# best:  0.49284707792952775  worst: 0.24859636727864115
# ----------------------------------
# finish prediction
# model :  495
# best:  0.48225913029445844  worst: 0.306550223541605
# ----------------------------------
# finish prediction
# model :  496
# best:  0.5252549482276988  worst: 0.3571816083553251
# ----------------------------------
# finish prediction
# model :  497
# best:  0.5020508695937729  worst: 0.3115726346283931
# ----------------------------------
# finish prediction
# model :  498
# best:  0.4414342738074601  worst: 0.1385937274340674
# ----------------------------------
# finish prediction
# model :  499
# best:  0.40356928018807403  worst: 0.2479807977473597
# ----------------------------------
# finish prediction
# model :  500
# best:  0.49079798978617784  worst: 0.2488649464940242
# ----------------------------------
# finish prediction
# model :  501
# best:  0.5160567878568416  worst: 0.33507244823473653
# ----------------------------------
# finish prediction
# model :  502
# best:  0.24209527337761297  worst: 0.06578364553236307
# ----------------------------------
# finish prediction
# model :  503
# best:  0.38767283010811904  worst: 0.2479940895633845
# ----------------------------------
# finish prediction
# model :  504
# best:  0.5138557505182089  worst: 0.34448585446139457
# ----------------------------------
# finish prediction
# model :  505
# best:  0.4006607409192489  worst: 0.248083433009115
# ----------------------------------
# finish prediction
# model :  506
# best:  0.5417763347483503  worst: 0.34053354834406935
# ----------------------------------
# finish prediction
# model :  507
# best:  0.5096751144315899  worst: 0.38102070095996343
# ----------------------------------
# finish prediction
# model :  508
# best:  0.5198819621290564  worst: 0.3321065072679966
# ----------------------------------
# finish prediction
# model :  509
# best:  0.5230022301480968  worst: 0.4386255966555454
# ----------------------------------
# finish prediction
# model :  510
# best:  0.6849649165670931  worst: 0.2518365164887983
# ----------------------------------
# finish prediction
# model :  511
# best:  0.5151510398916324  worst: 0.35986969573861405
# ----------------------------------
# finish prediction
# model :  512
# best:  0.539020601243196  worst: 0.2488917823526982
# ----------------------------------
# finish prediction
# model :  513
# best:  0.5026498907266104  worst: 0.24816978427317815
# ----------------------------------
# finish prediction
# model :  514
# best:  0.5144159700503625  worst: 0.309050482155121
# ----------------------------------
# finish prediction
# model :  515
# best:  0.29771760838461747  worst: 0.2482815683433882
# ----------------------------------
# finish prediction
# model :  516
# best:  0.6735213865189128  worst: 0.2522247371863942
# ----------------------------------
# finish prediction
# model :  517
# best:  0.5149391097303418  worst: 0.24858492953806635
# ----------------------------------
# finish prediction
# model :  518
# best:  0.5163372684339778  worst: 0.34586075446588754
# ----------------------------------
# finish prediction
# model :  519
# best:  0.756622195871169  worst: 0.2488666990609976
# ----------------------------------
# finish prediction
# model :  520
# best:  0.3281043949487027  worst: 0.006715921570662587
# ----------------------------------
# finish prediction
# model :  521
# best:  0.4677248407369514  worst: 0.2489089221449842
# ----------------------------------

# %%
# Plot the obtained results for volume 0 and axial slice 47 of the test set (density estimations)
# --------------------------- ADD YOUR CODE HERE ------------------------------
densityEstimations(pred_seg_2)
# ----------------------------------- END -------------------------------------
# Out:
# /var/folders/zg/czcljwg57wg8p52y8g_wjbn40000gn/T/ipykernel_35929/46242901.py:24: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(im_[np.argwhere(pred_ == 0)][:, 0], ax=axes[2], fill=True, color='#85929E', label='Background', legend=True)

# %%
visualize_best_and_worst_samples(pred_seg_2)

# %% [markdown]
# # Task 3: Deep supervised segmentation

# %% [markdown]
# Deep Learning (DL) methods achieve state-of-the-art results in many (medical) image analyzis applications, including segmentation. Here, you will implement and train a DL method to segment CSF, WM, GM, and background in brain MRI.

# %% [markdown]
# First, let's have a look at the individual channels of the segmentations.

# %%
import matplotlib.pyplot as plt
import copy
im = load_nii(val_files[0])
csf, wm, gm, background = np.zeros(im.shape), np.zeros(im.shape), np.zeros(im.shape), np.zeros(im.shape)
csf[segmentations_val[0]==1] = 1
wm[segmentations_val[0]==2] = 1
gm[segmentations_val[0]==3] = 1
background[segmentations_val[0]==0]=1
elements = [im, csf, wm, gm, background]
titles = ['Input', 'CSF', 'WM', 'GM', 'Background']
diffp, axarr = plt.subplots(1, len(elements), gridspec_kw={'wspace': 0, 'hspace': 0})
diffp.set_size_inches(len(elements) * 4, 4)
for idx_arr in range(len(axarr)):
    axarr[idx_arr].axis('off')
    el = np.squeeze(elements[idx_arr][:,:,47])
    axarr[idx_arr].imshow(el.T, cmap='gray')
    axarr[idx_arr].set_title(titles[idx_arr])

# %% [markdown]
# ## DL-based segmentation

# %% [markdown]
# Define and train a U-Net for segmentation (use the train, val, and test splits defined above).
#
# Feel free to choose:
# * the number of layers
# * the number of features within convolutional layers
# * number of convolutions within each layer
# * concatenation strategy
# * ...
#
# HINT: You can use pre-defined models, e.g., from torchvision, but train them from scratch (no pre-training)

# %%
# !python -c "import monai" || pip install -q "monai-weekly[tqdm, nibabel]"
# %matplotlib inline

# %%
from __future__ import annotations

import monai
from monai.apps.utils import download_and_extract
from monai.data import DataLoader, CacheDataset, list_data_collate
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric

from monai.networks.utils import one_hot
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference

import torch
from monai.networks.nets import UNet

root_dir = './model'
model_path =  os.path.join('./model', "new_image_size_model.pth")

# %%
from skimage.transform import resize
import torch.nn.functional as F
def load_data_from_list_3d(image_files, segmentation_files):
  # index =
  # [i,:,:,0] sagital
  # [:, i, : , 0] coronal
  # [:, : , i, 0] axial
  images = []
  labels = []
  # 98, 116, 94
  new_size = (98, 116, 94)
  for j in range(int(len(segmentation_files))):
  #for j in range(5):
    slice_images = nib.load(image_files[j]).get_fdata()
    # Assuming new_size is your desired size tuple (e.g., (height, width, depth))
    resized_img = resize(slice_images, new_size, anti_aliasing=True)
    slice_labels = segmentation_files[j]
    # Assuming new_size is your desired size tuple (e.g., (height, width, depth))
    resized_img = resize(slice_labels, new_size, anti_aliasing=True)
    resized_labels = resize(slice_labels, new_size, anti_aliasing=True)    
    slice_images = np.expand_dims(resized_img, axis=0)
    slice_labels = np.expand_dims(resized_labels, axis=0)
    images.append(slice_images)
    labels.append(slice_labels)
  return images, labels

# %%
train_images, train_labels = load_data_from_list_3d(train_files, segmentations_train)
train_img = [{"img": img, "seg": seg} for img, seg in (zip(train_images, train_labels))]
train_ds = CacheDataset(data=train_img,transform=None)
train_loader_3d = DataLoader(train_ds, batch_size=16, shuffle=False, collate_fn=list_data_collate, pin_memory=True)

val_images, val_labels = load_data_from_list_3d(val_files, segmentations_val)
val_img = [{"img": img, "seg": seg} for img, seg in zip(val_images, val_labels)]
val_ds = CacheDataset(data=val_img, transform=None)
val_loader_3d = DataLoader(val_ds, batch_size=16, shuffle=False, collate_fn=list_data_collate, pin_memory=True)

test_images, test_labels = load_data_from_list_3d(test_files, segmentations_test)
test_img = [{"img": img, "seg": seg} for img, seg in zip(test_images, test_labels)]
test_ds = CacheDataset(data=test_img, transform=None)
test_loader_3d = DataLoader(test_ds, batch_size=1, shuffle=False, collate_fn=list_data_collate, pin_memory=True)
# Out:
# Loading dataset: 100%|██████████| 522/522 [00:00<00:00, 1080664.70it/s]
# Loading dataset: 100%|██████████| 65/65 [00:00<00:00, 669851.99it/s]
# Loading dataset: 100%|██████████| 65/65 [00:00<00:00, 715563.67it/s]

# %%
def train_quicknat3D(model, train_loader, val_loader, view, model_path):
    learning_rate = 1e-3
    print(f"training of {view} UNet")
    best_model = None
    loss_function = DiceLoss(to_onehot_y=True, softmax=True)
    # optimizer = torch.optim.SGD(
    #     model.parameters(),
    #     lr=learning_rate,
    #     momentum=0.99,
    #     weight_decay=3e-5,
    #     nesterov=True,
    # )
    optimizer = torch.optim.Adam(model.parameters(), 1e-3)
    dice_metric = DiceMetric(include_background=False, reduction="mean")
    max_epochs = 20
    val_interval = 2
    best_metric = -1
    best_metric_epoch = -1
    epoch_loss_values = []
    metric_values = []


    # load pretrained model 
    if os.path.exists(model_path): 
        model.load_state_dict(torch.load(model_path))
        best_model = model.state_dict()
        # Compute the initial validation metric for the pre-loaded model
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["img"].to(device),
                    val_data["seg"].to(device),
                )
                roi_size = (98, 116, 94)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                labels_oneHot = one_hot(val_labels, 4)
                dice_metric(y_pred=val_outputs > 0.5, y=labels_oneHot)

            # aggregate the initial mean dice result
            initial_metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            best_metric = initial_metric
            print(f"Initial mean dice: {initial_metric:.4f}")
    
    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs, labels = (
                batch_data["img"].to(device),
                batch_data["seg"].to(device),
            )
            optimizer.zero_grad()
            outputs = model(inputs)
            print("outputs recived")
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            print(f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                for val_data in val_loader:
                    val_inputs, val_labels = (
                        val_data["img"].to(device),
                        val_data["seg"].to(device),
                    )
                    roi_size = (98, 116, 94)
                    sw_batch_size = 4
                    val_outputs = sliding_window_inference(val_inputs, roi_size, sw_batch_size, model)
                    labels_oneHot = one_hot(val_labels, 4)
                    # compute metric for current iteration
                    dice_metric(y_pred=val_outputs > 0.5 , y=labels_oneHot)

                # aggregate the final mean dice result
                metric = dice_metric.aggregate().item()
                # reset the status for next validation round
                dice_metric.reset()

                metric_values.append(metric)
                if metric > best_metric:
                    best_metric = metric
                    best_metric_epoch = epoch + 1
                    best_model = model.state_dict()
                    torch.save(model.state_dict(), model_path)
                    print("saved new best metric model")
                print(
                    f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                    f"\nbest mean dice: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )
    
    return best_model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model3d = UNet(spatial_dims = 3,
             in_channels = 1,
             out_channels=4,
             channels=(4, 8, 16, 32),
             strides=(1, 1, 1),
            #  channels=(4, 8, 16, 32, 64, 128),
            #  strides=(2, 2, 2, 2, 2),
            # channels=(16, 32, 64, 128, 256),
            # strides=(2, 2, 2, 2),
             num_res_units=2) 
model_test = train_quicknat3D(model3d, train_loader_3d, val_loader_3d, "3d", model_path)
# Out:
# training of 3d UNet
# ----------
# epoch 1/20
# outputs recived
# 1/32, train_loss: 0.7742
# outputs recived
# 2/32, train_loss: 0.7407
# outputs recived
# 3/32, train_loss: 0.7078
# outputs recived
# 4/32, train_loss: 0.7003
# outputs recived
# 5/32, train_loss: 0.6768
# outputs recived
# 6/32, train_loss: 0.6600
# outputs recived
# 7/32, train_loss: 0.6478
# outputs recived
# 8/32, train_loss: 0.6279
# outputs recived
# 9/32, train_loss: 0.6182
# outputs recived
# 10/32, train_loss: 0.6053
# outputs recived
# 11/32, train_loss: 0.5954
# outputs recived
# 12/32, train_loss: 0.5939
# outputs recived
# 13/32, train_loss: 0.5790
# outputs recived
# 14/32, train_loss: 0.5688
# outputs recived
# 15/32, train_loss: 0.5672
# outputs recived
# 16/32, train_loss: 0.5505
# outputs recived
# 17/32, train_loss: 0.5388
# outputs recived
# 18/32, train_loss: 0.5341
# outputs recived
# 19/32, train_loss: 0.5251
# outputs recived
# 20/32, train_loss: 0.5241
# outputs recived
# 21/32, train_loss: 0.5055
# outputs recived
# 22/32, train_loss: 0.5215
# outputs recived
# 23/32, train_loss: 0.4983
# outputs recived
# 24/32, train_loss: 0.4959
# outputs recived
# 25/32, train_loss: 0.4979
# outputs recived
# 26/32, train_loss: 0.4901
# outputs recived
# 27/32, train_loss: 0.4814
# outputs recived
# 28/32, train_loss: 0.4611
# outputs recived
# 29/32, train_loss: 0.4523
# outputs recived
# 30/32, train_loss: 0.4603
# outputs recived
# 31/32, train_loss: 0.4421
# outputs recived
# 32/32, train_loss: 0.4442
# outputs recived
# 33/32, train_loss: 0.4319
# epoch 1 average loss: 0.5612
# ----------
# epoch 2/20
# outputs recived
# 1/32, train_loss: 0.4364
# outputs recived
# 2/32, train_loss: 0.4299
# outputs recived
# 3/32, train_loss: 0.4138
# outputs recived
# 4/32, train_loss: 0.4337
# outputs recived
# 5/32, train_loss: 0.4061
# outputs recived
# 6/32, train_loss: 0.3855
# outputs recived
# 7/32, train_loss: 0.3942
# outputs recived
# 8/32, train_loss: 0.3708
# outputs recived
# 9/32, train_loss: 0.3670
# outputs recived
# 10/32, train_loss: 0.3633
# outputs recived
# 11/32, train_loss: 0.3590
# outputs recived
# 12/32, train_loss: 0.3651
# outputs recived
# 13/32, train_loss: 0.3506
# outputs recived
# 14/32, train_loss: 0.3434
# outputs recived
# 15/32, train_loss: 0.3457
# outputs recived
# 16/32, train_loss: 0.3289
# outputs recived
# 17/32, train_loss: 0.3196
# outputs recived
# 18/32, train_loss: 0.3170
# outputs recived
# 19/32, train_loss: 0.3122
# outputs recived
# 20/32, train_loss: 0.3129
# outputs recived
# 21/32, train_loss: 0.2946
# outputs recived
# 22/32, train_loss: 0.3129
# outputs recived
# 23/32, train_loss: 0.2920
# outputs recived
# 24/32, train_loss: 0.2894
# outputs recived
# 25/32, train_loss: 0.2934
# outputs recived
# 26/32, train_loss: 0.2886
# outputs recived
# 27/32, train_loss: 0.2819
# outputs recived
# 28/32, train_loss: 0.2638
# outputs recived
# 29/32, train_loss: 0.2571
# outputs recived
# 30/32, train_loss: 0.2619
# outputs recived
# 31/32, train_loss: 0.2489
# outputs recived
# 32/32, train_loss: 0.2517
# outputs recived
# 33/32, train_loss: 0.2412
# epoch 2 average loss: 0.3313
# saved new best metric model
# current epoch: 2 current mean dice: 0.5680
# best mean dice: 0.5680 at epoch: 2
# ----------
# epoch 3/20
# outputs recived
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#       1 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#       2 model3d = UNet(spatial_dims = 3,
#       3              in_channels = 1,
#       4              out_channels=4,
#    (...)
#      10             # strides=(2, 2, 2, 2),
#      11              num_res_units=2)
# ---> 12 model_test = train_quicknat3D(model3d, train_loader_3d, val_loader_3d, "3d", model_path)
#
# Cell In[9], line 65, in train_quicknat3D(model, train_loader, val_loader, view, model_path)
#      63 print("outputs recived")
#      64 loss = loss_function(outputs, labels)
# ---> 65 loss.backward()
#      66 optimizer.step()
#      67 epoch_loss += loss.item()
#
# File ~/opt/anaconda3/envs/i2dl/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/opt/anaconda3/envs/i2dl/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
import torch.nn.functional as F

def get_prediction(model, test_loader, model_path):
    combined_tensors = []
    model.load_state_dict(torch.load(model_path))
    model.eval()
    new_size = (98, 116, 94)
    for i, batch_data in enumerate(test_loader):
        # Get predictions for image
        pred = model(batch_data["img"]).argmax(dim=1)
        current_size = pred.shape[1:]

        # Use interpolate to resize the tensor to the target size
        resized_tensor = F.interpolate(pred.unsqueeze(0).float(), size=new_size, mode='nearest').long().squeeze(0)

        # Append the resized tensor to the list
        combined_tensors.append(resized_tensor.squeeze(0))

    return combined_tensors

# %%
# Define and train a neural network (U-Net) for segmentation
# Implement
# --------------------------- ADD YOUR CODE HERE ------------------------------
pred_seg_3 = get_prediction(model3d, test_loader_3d, model_path)
# ----------------------------------- END -------------------------------------

# %% [markdown]
# ### Evaluate the Dice scores (separately for every tissue type) for the whole test set.

# %%
# Visualize individual segmentation channels for axial slice 47 of all three approaches and the ground truth in a similar style as above
# Implement
# --------------------------- ADD YOUR CODE HERE ------------------------------
def plot_axial_segmentations(im: np.ndarray, seg: np.ndarray, gt: np.ndarray, i: int = 65, title: str = None):
    fig, ax = plt.subplots(1, 2, figsize=(20, 10))

    ax[0].imshow(np.rot90(im[..., i], k=3), cmap='gray')
    ax[0].imshow(np.rot90(seg[..., i], k=3),
                 alpha=0.5 * (np.rot90(seg[..., i] > 0, k=3)),
                 interpolation=None, cmap='jet')
    ax[0].set_title('Prediction')
    ax[1].imshow(np.rot90(im[..., i], k=3), cmap='gray')
    ax[1].imshow(np.rot90(gt[..., i], k=3),
                 alpha=0.5 * (np.rot90(seg[..., i] > 0, k=3)),
                 interpolation=None, cmap='jet')
    ax[1].set_title('Ground Truth')

    if title is not None:
        # plt.set_title(title)
        fig.suptitle(title, fontsize=16)

    plt.tight_layout()
    plt.show()

def visualize_best_sample(predictions, i_best=47):
    return_dict = get_best_and_worst_ids(predictions)
    best_id = return_dict['best_id']
    plot_axial_segmentations(load_nii(test_files[best_id]), predictions[best_id], segmentations_test[best_id], i=i_best,
                       title=f'Best prediction on the test set')

visualize_best_sample(pred_seg_1)
visualize_best_sample(pred_seg_2)
visualize_best_sample(pred_seg_3)

plt_seg_1 = None
plt_seg_2 = None
plt_seg_3 = None
plt_gt = None
# ----------------------------------- END -------------------------------------
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 32
#      28     plot_axial_segmentations(load_nii(test_files[best_id]), predictions[best_id], segmentations_test[best_id], i=i_best,
#      29                        title=f'Best prediction on the test set')
#      31 visualize_best_sample(pred_seg_1)
# ---> 32 visualize_best_sample(pred_seg_2)
#      33 visualize_best_sample(pred_seg_3)
#      35 plt_seg_1 = None
#
# NameError: name 'pred_seg_2' is not defined

# %%
# Run this block after implementing Q3.
visualize_best_and_worst_samples(pred_seg_3)

# %% [markdown]
# ### Summarize the results of all of the segmentation methods implemented.

# %%
# Run this block after implementing Q1-3.
results_dictionary = {
    'unsupervised1': get_results_dictionary(pred_seg_1),
    'unsupervised2': get_results_dictionary(pred_seg_2),
    'u-net': get_results_dictionary(pred_seg_3),
}
plot_results_summary(results_dictionary)
